# %% [markdown]
# # Generating Data

# %%
import pandas as pd

from bs4 import BeautifulSoup

from tqdm.notebook import tqdm

import re

import os

# %%
def extract_price_and_cuisine(input_string):
    # Extract price range (sequence of '€')
    price_range = re.search(r'€+', input_string)
    price_range = price_range.group() if price_range else ''
    
    # Extract cuisine type (after last '·')
    cuisine = input_string.split('·')[-1].strip()
    
    return price_range, cuisine

# %%
os.makedirs(f"restaurants_parsed_data", exist_ok=True)
folders = list(range(1,101))
rest_n = 1

for fol in tqdm(folders):

    # get files in page i folder and order them based on retaurants
    files = os.listdir(f'page {fol}')
    files = sorted(files, key=lambda x: int(re.search(r'(\d+)', x).group()))

    for rest in files:
        # Load restraurant URLs
        with open(f'page {fol}' + '/' + rest, "r") as file:
            html = file.read()
        
        # MakeH HTML BeautifulSoup object
        html = BeautifulSoup(html, features='lxml')

        # Restaurant name
        restaurantName = html.select_one('h1', {'class' : 'data-sheet__title'}).text.strip()

        if restaurantName == '':
            print(f'restaurantName is missing in {rest}')

        # Restaurant location
        location = html.find_all('div', {'class' : 'data-sheet__block--text'})[0].text.strip()
        location = location.split(',')

        address = location[0]
        city = location[1]
        postalCode = location[2]
        country = location[3]
        
        if address == '':
            print(f'address is missing in {rest}')
        if city == '':
            print(f'city is missing in {rest}')
        if postalCode == '':
            print(f'postalCode is missing in {rest}')
        if country == '':
            print(f'country is missing in {rest}')
        
        # Restaurant characteristics
        attributes = html.find_all('div', {'class' : 'data-sheet__block--text'})[1].text.strip()
        # attributes = attributes.split()

        # priceRange = attributes[0]
        # cuisineType = attributes[-2] + attributes[-1]
        priceRange, cuisineType = extract_price_and_cuisine(attributes)

        if priceRange == '':
            print(f'priceRange is missing in {rest}')
        if cuisineType == '':
            print(f'cuisineType is missing in {rest}')


        # Restaurant desctiption
        if len(html.find_all('div', {'class' : 'data-sheet__description'})) != 0:
            description = html.find_all('div', {'class' : 'data-sheet__description'})[0].text.strip()
        else:
            print(f'description is missing in {rest}')
            description = ''
            

        # Restaurant services
        services = html.find_all('div', {'class' : 'col col-12 col-lg-6'})

        for ser in services:
            if len(ser.find_all('div')) == 0 :
                facilitiesServices = [x.text.strip() for x in ser.find_all('li')]
            else:
                creditCards = [x['data-src'].split('/')[-1].split('-')[0].capitalize() for x in ser.find_all('img')]
        
        if len(facilitiesServices) == 0:
            print(f'facilitiesServices is missing in {rest}')
        if len(creditCards) == 0:
            print(f'creditCards is missing in {rest}')

        # Restaurant phone number
        if len(html.find_all('a', {'data-event' : 'CTA_tel'})) !=0:
            phoneNumber = html.find_all('a', {'data-event' : 'CTA_tel'})[0]['href'].replace('tel:', '')
        else:
            print(f'phoneNumber is missing in {rest}')
            phoneNumber = ''

        # Restaurant website
        if len(html.find_all('a', {'data-event' : 'CTA_website'})) != 0:
            website = html.find_all('a', {'data-event' : 'CTA_website'})[0]['href']
        else:
            print(f'website is missing in {rest}')
            website = ''

        # Make dictionary
        restaurant_data = {
                "restaurantName": restaurantName,                # string
                "address": address,                              # string
                "city": city,                                    # string
                "postalCode": postalCode,                        # string
                "country": country,                              # string
                "priceRange": priceRange,                        # string
                "cuisineType": cuisineType,                      # string
                "description": description,                      # string
                "facilitiesServices": ",".join(facilitiesServices),        # list of strings, actually string (impossible to save list in tsv file)
                "creditCards": ",".join(creditCards),                      # list of strings, actually string (impossible to save list in tsv file)
                "phoneNumber": phoneNumber,                      # string
                "website": website                               # string
            }
        
        # List of restaurant data 
        data = [restaurant_data]

        # Save as TSV
        df = pd.DataFrame(data)
        df.to_csv(f"restaurants_parsed_data/restaurant_{rest_n}.tsv", sep="\t", index=False, header=False)

        rest_n += 1
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0), HTML(value='')))
# website is missing in restaurant_22.html
# website is missing in restaurant_73.html
# website is missing in restaurant_80.html
# website is missing in restaurant_87.html
# website is missing in restaurant_125.html
# website is missing in restaurant_129.html
# website is missing in restaurant_144.html
# website is missing in restaurant_159.html
# website is missing in restaurant_169.html
# website is missing in restaurant_178.html
# website is missing in restaurant_192.html
# website is missing in restaurant_228.html
# website is missing in restaurant_261.html
# website is missing in restaurant_278.html
# website is missing in restaurant_282.html
# website is missing in restaurant_288.html
# website is missing in restaurant_305.html
# website is missing in restaurant_310.html
# website is missing in restaurant_320.html
# website is missing in restaurant_324.html
# website is missing in restaurant_326.html
# website is missing in restaurant_354.html
# website is missing in restaurant_394.html
# website is missing in restaurant_404.html
# website is missing in restaurant_407.html
# website is missing in restaurant_422.html
# website is missing in restaurant_441.html
# website is missing in restaurant_471.html
# website is missing in restaurant_478.html
# website is missing in restaurant_488.html
# website is missing in restaurant_552.html
# website is missing in restaurant_557.html
# website is missing in restaurant_566.html
# website is missing in restaurant_603.html
# website is missing in restaurant_608.html
# website is missing in restaurant_619.html
# website is missing in restaurant_629.html
# website is missing in restaurant_632.html
# website is missing in restaurant_662.html
# website is missing in restaurant_676.html
# website is missing in restaurant_682.html
# website is missing in restaurant_689.html
# website is missing in restaurant_694.html
# website is missing in restaurant_718.html
# website is missing in restaurant_727.html
# website is missing in restaurant_728.html
# website is missing in restaurant_730.html
# website is missing in restaurant_739.html
# website is missing in restaurant_790.html
# website is missing in restaurant_791.html
# website is missing in restaurant_794.html
# website is missing in restaurant_802.html
# website is missing in restaurant_823.html
# website is missing in restaurant_857.html
# website is missing in restaurant_885.html
# website is missing in restaurant_913.html
# website is missing in restaurant_932.html
# website is missing in restaurant_950.html
# website is missing in restaurant_957.html
# website is missing in restaurant_962.html
# website is missing in restaurant_964.html
# website is missing in restaurant_991.html
# website is missing in restaurant_999.html
# website is missing in restaurant_1069.html
# website is missing in restaurant_1196.html
# website is missing in restaurant_1210.html
# website is missing in restaurant_1228.html
# website is missing in restaurant_1230.html
# website is missing in restaurant_1264.html
# website is missing in restaurant_1273.html
# website is missing in restaurant_1285.html
# website is missing in restaurant_1290.html
# website is missing in restaurant_1369.html
# website is missing in restaurant_1370.html
# website is missing in restaurant_1373.html
# website is missing in restaurant_1424.html
# website is missing in restaurant_1436.html
# website is missing in restaurant_1441.html
# website is missing in restaurant_1459.html
# website is missing in restaurant_1478.html
# website is missing in restaurant_1479.html
# website is missing in restaurant_1484.html
# website is missing in restaurant_1492.html
# website is missing in restaurant_1512.html
# website is missing in restaurant_1523.html
# website is missing in restaurant_1552.html
# website is missing in restaurant_1597.html
# website is missing in restaurant_1616.html
# website is missing in restaurant_1655.html
# website is missing in restaurant_1663.html
# postalCode is missing in restaurant_1670.html
# website is missing in restaurant_1680.html
# website is missing in restaurant_1681.html
# website is missing in restaurant_1693.html
# website is missing in restaurant_1699.html
# website is missing in restaurant_1709.html
# website is missing in restaurant_1717.html
# website is missing in restaurant_1729.html
# website is missing in restaurant_1732.html
# website is missing in restaurant_1742.html
# website is missing in restaurant_1768.html
# website is missing in restaurant_1816.html
# website is missing in restaurant_1817.html
# website is missing in restaurant_1819.html
# website is missing in restaurant_1825.html
# website is missing in restaurant_1894.html
# website is missing in restaurant_1913.html
# website is missing in restaurant_1923.html
# website is missing in restaurant_1930.html

# %% [markdown]
# # Check Generated Data

# %%
pd.set_option('display.max_rows', None)

# %%
# List of file paths (or you can use a pattern to match all TSV files)
file_paths = os.listdir('restaurants_parsed_data')  # Replace with your actual file names or paths
file_paths = ['restaurants_parsed_data/' + i for i in file_paths]

# Read all files and store them in a list of DataFrames
dfs = [pd.read_csv(file, sep='\t', header=None, names = ['restaurantName', 'address', 'city', 'postalCode', 'country', 'priceRange', 'cuisineType',
                                                             'description', 'facilitiesServices', 'creditCards', 'phoneNumber', 'website']) for file in tqdm(file_paths)]

# Concatenate all DataFrames into one
combined_df = pd.concat(dfs, ignore_index=True)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=1982.0), HTML(value='')))

# %%
combined_df.head(10)
# Out:
#                             restaurantName                     address  \
# 0                           O Me O Il Mare              Via Roma 45/47
# 1                           Alessandro Feo         via Angelo Lista 24
# 2                                 Lalibera          via Pertinace 24/a
# 3  Antica Macelleria Cecchini - Solociccia          via Chiantigiana 5
# 4                                   Brindo              via Libertà 18
# 5                                Edelweiss              Località Crodo
# 6                                Ceresio 7               via Ceresio 7
# 7                         Impronta d'Acqua            via Aurelia 2121
# 8                                    Imàgo  piazza Trinità dei Monti 6
# 9                     L'Aia dei Cappellani            contrada Maurino
#
#                       city postalCode country priceRange  \
# 0                 Gragnano      80054   Italy       €€€€
# 1   Marina di Casal Velino      84040   Italy         €€
# 2                     Alba      12051   Italy         €€
# 3                  Panzano      50022   Italy         €€
# 4                   Cusago      20047   Italy          €
# 5                   Viceno      28862   Italy          €
# 6                    Milan      20154   Italy        €€€
# 7          Cavi di Lavagna      16030   Italy        €€€
# 8                     Rome        187   Italy       €€€€
# 9                Trecchina      85049   Italy          €
#
#                             cuisineType  \
# 0  Italian Contemporary, Modern Cuisine
# 1                    Campanian, Seafood
# 2      Piedmontese, Traditional Cuisine
# 3                      Meats and Grills
# 4                            Lombardian
# 5     Country cooking, Seasonal Cuisine
# 6                        Modern Cuisine
# 7        Italian Contemporary, Creative
# 8                  Italian Contemporary
# 9  Country cooking, Traditional Cuisine
#
#                                          description  \
# 0  After many years’ experience in Michelin-starr...
# 1  In a beautiful stone-vaulted building (an old ...
# 2  A modern, designer-style restaurant staffed by...
# 3  One of the most famous butchers in Italy has n...
# 4  The service is characterized by a cohesive and...
# 5  A real bastion of local cuisine for over 60 ye...
# 6  This designer-style restaurant is housed on th...
# 7  Situated on the straight road skirting the sea...
# 8  The location of this rooftop restaurant could ...
# 9  In the dining room there are old photos and eq...
#
#                                   facilitiesServices  \
# 0  Air conditioning,Interesting wine list,Wheelch...
# 1         Air conditioning,Terrace,Wheelchair access
# 2             Air conditioning,Interesting wine list
# 3  Air conditioning,Bring your own bottle,Restaur...
# 4                                   Air conditioning
# 5          Car park,Garden or park,Wheelchair access
# 6                Air conditioning,Great view,Terrace
# 7  Air conditioning,Restaurant offering vegetaria...
# 8  Air conditioning,Great view,Interesting wine list
# 9                  Air conditioning,Car park,Terrace
#
#                                          creditCards       phoneNumber  \
# 0                    Amex,Dinersclub,Mastercard,Visa  +39 081 620 0550
# 1                    Amex,Dinersclub,Mastercard,Visa  +39 328 893 7083
# 2                               Amex,Mastercard,Visa   +39 0173 293155
# 3                               Amex,Mastercard,Visa    +39 055 852020
# 4                               Amex,Mastercard,Visa  +39 02 9039 4429
# 5                    Amex,Dinersclub,Mastercard,Visa   +39 0324 618791
# 6                    Amex,Dinersclub,Mastercard,Visa  +39 02 3103 9221
# 7                    Amex,Dinersclub,Mastercard,Visa  +39 375 529 1077
# 8  Amex,Unionpay,Dinersclub,Jcb,Maestrocard,Maste...  +39 06 6993 4726
# 9                                    Mastercard,Visa   +39 0973 826937
#
#                                              website
# 0                              http://omeoilmare.com
# 1            https://www.alessandrofeoristorante.it/
# 2                              https://lalibera.com/
# 3                      https://www.dariocecchini.com
# 4                              https://www.brindo.it
# 5       https://www.albergoedelweiss.com/ristorante/
# 6                           https://www.ceresio7.com
# 7                    https://www.improntadacqua.com/
# 8  https://www.hotelhasslerroma.com/it/ristoranti...
# 9                 https://www.laiadeicappellani.com/
