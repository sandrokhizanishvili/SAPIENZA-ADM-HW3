# %%
import pandas as pd
import numpy as np

import string

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.stem import SnowballStemmer

import os
import re

from tqdm.notebook import tqdm

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jacopocaldana/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jacopocaldana/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def preprocess_text(text):

    # Initialize stopwords, stemmer, and punctuation
    stop_words = set(stopwords.words("english"))
    stemmer = PorterStemmer()

    # Convert to lowercase
    text = text.lower()
    # Tokenize
    words = word_tokenize(text)
    # Remove stopwords, punctuation, and apply stemming
    processed_words = [
        stemmer.stem(word)  # Apply stemming
        for word in words
        if word not in stop_words and word not in string.punctuation and word.isalnum()
    ]
    return ' '.join(processed_words)

# %%
def preprocess_text(text):
    # Initialize stopwords, stemmer, and punctuation
    stop_words = set(stopwords.words("english"))
    stemmer = SnowballStemmer("english")
    

    # Convert to lowercase
    text = text.lower()
    
    text = re.sub(r'\b0\w*\b', '', text) # Remove words that begin with the digit 0
    # text = re.sub(r"[^a-zA-Z0-9\s]", "", text) # Keep only letters and numbers
    # text = re.sub(r"\n", " ", text) # Remove newline
    # text = text.strip() # Remove leading and trailing whitespaces
    # text = re.sub(' +', ' ', text) # Remove multiple whitespaces
    
    # Tokenize
    words = word_tokenize(text)
    
    # Remove stopwords, punctuation, apply stemming, filter out short words and exclude non alphanumeric words if they exist.
    processed_words = [
        stemmer.stem(word)  # Apply stemming
        
        for word in words
        if word not in stop_words and 
           word not in string.punctuation and 
           word.isalnum() and # Exclude
           len(word) > 2  # Exclude very short words
    ]
    return ' '.join(processed_words)

# %%
# List of file paths (or you can use a pattern to match all TSV files)
file_paths = os.listdir('restaurants_parsed_data')  # Replace with your actual file names or paths
file_paths = ['restaurants_parsed_data/' + i for i in file_paths]

# Read all files and store them in a list of DataFrames
dfs = [pd.read_csv(file, sep='\t') for file in tqdm(file_paths)]

# Concatenate all DataFrames into one
df = pd.concat(dfs, ignore_index=True)
# Out:
#   0%|          | 0/1982 [00:00<?, ?it/s]

# %%
restaurant_descriptions = df['description'].values

# %%
processed_descriptions = [preprocess_text(description) for description in restaurant_descriptions]

# %%
def create_vocabulary(df):
    
    # Concatenate all preprocessed descriptions into a single list
    all_descriptions = ' '.join(df['description'].tolist())
    
    # Preprocess the concatenated text
    processed_descriptions = preprocess_text(all_descriptions)
    
    # Get unique terms
    unique_terms = sorted(set(processed_descriptions.split()))
    # Create vocabulary DataFrame
    vocab_df = pd.DataFrame({
        'term_id': range(len(unique_terms)),
        'term': unique_terms
    })
    
    # Save vocabulary to CSV
    vocab_df.to_csv('vocabulary.csv', index=False)
    
    print(f"Created vocabulary with {len(vocab_df)} unique terms")
    # Read all files and store them in a list of DataFrames
dfs = [pd.read_csv(file, sep='\t') for file in tqdm(file_paths)]

# Concatenate all DataFrames into one
df = pd.concat(dfs, ignore_index=True)

# Create vocabulary
create_vocabulary(df)
# Out:
#   0%|          | 0/1982 [00:00<?, ?it/s]
# Created vocabulary with 6956 unique terms

# %%
import csv

# %%
def build_inverted_index(processed_descriptions):
    
    inverted_index = {}
    
    # Load the existing vocabulary from the CSV file
    vocabulary = {}
    with open('vocabulary.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            vocabulary[row['term']] = int(row['term_id'])
    
    for restaurant_id, description in enumerate(processed_descriptions):
        for term in str(description).lower().split():
            if term in vocabulary:
                term_id = vocabulary[term]
                if term_id not in inverted_index:
                    inverted_index[term_id] = []
                if restaurant_id not in inverted_index[term_id]:
                   inverted_index[term_id].append(restaurant_id)
    
    return inverted_index

# %%
def search_restaurants(query, inverted_index, df):
    # Load the vocabulary from the CSV file
    vocabulary = {}
    with open('vocabulary.csv', 'r') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            vocabulary[row['term']] = int(row['term_id'])
    
    # Preprocess the query
    query_terms = set(preprocess_text(query).split())
    print(query_terms)
    
    # Find the intersection of restaurant IDs that contain all query terms
    matching_restaurant_ids = None
    for term in query_terms:
        if term in vocabulary:
            term_id = vocabulary[term]
            if term_id in inverted_index:
                if matching_restaurant_ids is None:
                    matching_restaurant_ids = set(inverted_index[term_id])
                else:
                    matching_restaurant_ids.intersection_update(set(inverted_index[term_id]))
    print(matching_restaurant_ids)
    # If no matching restaurants, return an empty DataFrame
    if matching_restaurant_ids is None or not matching_restaurant_ids:
        return pd.DataFrame(columns=['Restaurant Name', 'Address', 'Description', 'Website'])
    
    # Construct the output DataFrame of matching restaurants
    matching_restaurants = pd.DataFrame({
        'Restaurant Name': df.loc[list(matching_restaurant_ids), 'restaurantName'],
        'Address': df.loc[list(matching_restaurant_ids), 'address'],
        'Description': df.loc[list(matching_restaurant_ids), 'description'],
        'Website': df.loc[list(matching_restaurant_ids), 'website']
    })
    
    return matching_restaurants

# %%
query="modern seasonal cuisine"
inverted_index=build_inverted_index(processed_descriptions)
search_restaurants(query,inverted_index,df)
# Out:
# {'modern', 'season', 'cuisin'}
# {512, 387, 391, 904, 265, 266, 526, 1551, 1430, 1950, 801, 546, 676, 1192, 172, 46, 177, 1587, 1971, 1463, 1592, 1852, 830, 63, 1475, 840, 1356, 1105, 1236, 601, 1504, 1634, 1765, 485, 364, 492, 628, 757, 1270, 1527, 1147}
#                       Restaurant Name                             Address  \
# 512                              Saur                via Filippo Turati 8
# 387     Gallery Bistrot Contemporaneo           via Regina Margherita 3/b
# 391           Materia | Spazio Cucina               via Teatro Massimo 29
# 904                         Ronchi Rò         località Cime di Dolegna 12
# 265                         Contrasto                         via Roma 55
# 266                         Chichibio             via Guglielmo Marconi 1
# 526                       San Michele          via Castello di Fagagna 33
# 1551                 Le Vie del Borgo                   via alla Piazza 6
# 1430                             Savô                 piazza XXV Aprile 8
# 1950                  Casin del Gamba               via Roccolo Pizzati 1
# 801                           Sintesi                viale dei Castani 17
# 546             Il Luogo Aimo e Nadia                  via Montecuccoli 6
# 676                     Osteria Ophis           corso Serpente Aureo 54/b
# 1192                         La Valle                    via Umberto I 25
# 172                        RistoFante                      via Mazzini 41
# 46                            Il Tino                via Monte Cadria 127
# 177                       Pipero Roma      corso Vittorio Emanuele II 250
# 1587                    Secondo Tempo              via Vittorio Amedeo 55
# 1971           Winter Garden Florence                 piazza Ognissanti 1
# 1463                         [àbitat]                  via Henry Dunant 1
# 1592                     Piccolo Lord         corso San Maurizio 69 bis/g
# 1852                         Saporium             località Palazzetto 110
# 830                           Aprudia                  largo del Forno 16
# 63                             Flurin                       Laubengasse 2
# 1475                             Mima                    via Madonnelle 9
# 840                           Babette                 via Michelangelo 17
# 1356                            Razzo               via Andrea Doria 17/f
# 1105                       Vesta Mare                       viale Roma 41
# 1236  Cappuccini Cucina San Francesco                   via Cappuccini 54
# 601                          Radimare  via Beato Piergiorgio Frassati 5/a
# 1504                      San Giorgio           viale Brigate Bisagno 69r
# 1634                     Ca' Del Moro                   località Erbin 31
# 1765                      La Bandiera                  contrada Pastini 4
# 485                         Zum Löwen                       via Tirolo 25
# 364                   Osteria Taviani      piazza Vittorio Emanuele II 28
# 492                      Retrobottega               via della Stelletta 4
# 628                   Locanda Solagna                piazza I  Novembre 2
# 757           Osteria del Miglio 2.10                      via Patrioti 2
# 1270                        Esplanade                         via Lario 3
# 1527                   Quadri Bistrot                    Via Solferino 48
# 1147           Degusteria del Gigante                 via degli Anelli 19
#
#                                             Description  \
# 512   In a tiny rural village, this contemporary, al...
# 387   Modern, tasty and carefully curated cuisine, w...
# 391   The entrance to this restaurant is typical of ...
# 904   Ronchi Rò is an estate-cum-agriturismo surroun...
# 265   Having returned to his native village, owner-c...
# 266   Despite its lack of awards, this restaurant st...
# 526   Situated next to the ruins of the old castle a...
# 1551  Le Vie del Borgo is situated in a restored rus...
# 1430  The reopening in 2022 of the Hotel Windsor wit...
# 1950  The journey to get here – a winding road throu...
# 801   A modern, welcoming restaurant whose motto “Tr...
# 546   This long-established restaurant has been part...
# 676   Situated in the beautiful historic centre of O...
# 1192  A well - run restaurant in a quiet area just o...
# 172   The motto of this restaurant is “In step with ...
# 46    Enjoying an attractive location in the Nautilu...
# 177   Situated opposite the church of Santa Maria in...
# 1587  Situated on the first floor of a building (for...
# 1971  Horse-drawn carriages once entered the old cou...
# 1463  A young, enthusiastic and professional couple ...
# 1592  Professional service in a welcoming, modern re...
# 1852  Saporium is the new fine-dining restaurant at ...
# 830   At this restaurant in the historic centre, whe...
# 63    Flurin occupies an old medieval tower in Glore...
# 1475  You’ll be won over by the seasonal Mediterrane...
# 840   Situated just beyond the centre of Albenga in ...
# 1356  A quiet restaurant with a relaxed, young and m...
# 1105  This typical, elegant Versilian beach club wit...
# 1236  Housed in the resort of the same name, this el...
# 601   There’s no tasting menu at this restaurant but...
# 1504  Situated in the city albeit not right in the c...
# 1634  Situated within the La Collina dei Ciliegi win...
# 1765  Although it takes a while to reach this restau...
# 485   A charming restaurant housed in a skilfully re...
# 364   This pleasant, warmly decorated restaurant is ...
# 492   Minimalist decor and clean lines characterise ...
# 628   Although this restaurant has been in business ...
# 757   Although the town may not be of major importan...
# 1270  One of Italy’s long-established restaurants, t...
# 1527  A modern bistro with a cocktail-bar, trendy de...
# 1147  Situated in the charming historic centre of th...
#
#                                                Website
# 512                          https://ristorantesaur.it
# 387                                                NaN
# 391                https://www.materiaspaziocucina.it/
# 904                            https://www.ronchiro.it
# 265                     https://contrastoristorante.it
# 266                                                NaN
# 526                       http://sanmichele.restaurant
# 1551           https://www.leviedelborgoguesthouse.it/
# 1430                          http://www.thewindsor.it
# 1950                     https://www.casindelgamba.it/
# 801                        http://ristorantesintesi.it
# 546   https://www.aimoenadia.com/il-luogo-aimo-e-nadia
# 676                      https://www.osteriaophis.com/
# 1192                 https://www.ristorantelavalle.it/
# 172                         https://www.ristofante.it/
# 46                   https://www.ristoranteiltino.com/
# 177                         https://www.piperoroma.it/
# 1587              http://www.ristorantesecondotempo.it
# 1971          https://www.wintergardenflorence.com/it/
# 1463                      https://www.abitatproject.it
# 1592             https://www.ristorantepiccololord.it/
# 1852    http://www.saporium.com/it/borgo-santo.pietro/
# 830                             http://www.aprudia.com
# 63                               https://www.flurin.it
# 1475                  http://www.domo20.com/restaurant
# 840                 https://www.ristorantebabette.net/
# 1356                            https://vadoarazzo.it/
# 1105                https://vestafiorichiari.com/mare/
# 1236                        https://www.cappuccini.it/
# 601                            http://www.radimare.com
# 1504        https://www.ristorantesangiorgiogenova.it/
# 1634                     https://www.cadelmoro.wine/it
# 1765                        https://www.labandiera.it/
# 485                                                NaN
# 364                                                NaN
# 492                      https://www.retro-bottega.com
# 628                     https://www.locandasolagna.it/
# 757                                                NaN
# 1270             https://www.ristorante-esplanade.com/
# 1527                     https://www.quadribistrot.it/
# 1147              https://www.degusteriadelgigante.it/
