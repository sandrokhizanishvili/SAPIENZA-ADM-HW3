# %% [markdown]
# # 5. BONUS: Advanced Search Engine
#
# This section implements an advanced search engine that allows users to query a dataset of restaurants using multiple filters. The system combines text-based search with additional filters such as price range, accepted credit cards, and offered services to deliver highly relevant results.

# %%
import ipywidgets as widgets
from IPython.display import display

import pandas as pd
import re
from nltk.corpus import stopwords

from collections import defaultdict

# %% [markdown]
# The following cell defines the **`UserInputInterface`** class, designed to create an interactive user interface using **ipywidgets**. The goal is to allow users to specify advanced search criteria for restaurants.
#
# Users can specify search terms for the following features (some or all):
# - **restaurantName**
# - **city**
# - **cuisineType**
#
# The other tabs are for filtering by:
# - **price range**
# - **Region**
# - **Accepted credit cards**
# - **Offered services**

# %%
class UserInputInterface:
    def __init__(self):

        layout_with_description = widgets.Layout(width='50%')
        label_layout = widgets.Layout(description_width='150px')
        
        self.restaurant_name = widgets.Text(placeholder='Name of restaurant', description='Restaurant:')
        self.city = widgets.Text(placeholder='City', description='City:')
        self.cuisine_type = widgets.Text(placeholder='Cucine type', description='Cucine:')

        price_options = {
            '€': 1,
            '€€': 2,
            '€€€': 3,
            '€€€€': 4
        }

        self.price_range = widgets.SelectionRangeSlider(
            options=list(price_options.keys()),
            index=(0, 3),
            description='Price:',
            continuous_update=False
        )

        self.regions = widgets.SelectMultiple(
            options=['Abruzzo', 'Basilicata', 'Calabria', 'Campania', 'Emilia-Romagna', 
                     'Friuli Venezia Giulia', 'Lazio', 'Liguria', 'Lombardia', 'Marche', 
                     'Molise', 'Piemonte', 'Puglia', 'Sardegna', 'Sicilia', 'Toscana', 
                     'Trentino-Alto Adige', 'Umbria', 'Valle d\'Aosta', 'Veneto'],
            description='Region:',
            rows=7
        )

        credit_card_options = ['Amex', 'Dinersclub', 'Mastercard', 'Visa', 'Discover', 'JCB', 'Unionpay', 'Maestro', 'CartaSi']
        self.credit_card_checkboxes = [widgets.Checkbox(value=False, description=card) for card in credit_card_options]

        self.credit_cards_grid = widgets.GridBox(
            children=self.credit_card_checkboxes,
            layout=widgets.Layout(grid_template_columns="repeat(3, 1fr)", gap="10px")
        )

        self.facilities = widgets.SelectMultiple(
            options=['Air conditioning', 'Interesting wine list', 'Wheelchair access', 'Terrace', 'Counter dining',
                     'Great view', 'Garden or park', 'Car park', 'Restaurant offering vegetarian menus', 'Brunch','Valet parking'],
            description='Services:',
            rows=11,
            layout=widgets.Layout(width='400px')
        )

        self.output = widgets.Output()
        self.search_button = widgets.Button(description="Start Search")
        self.search_button.on_click(self.on_search_button_clicked)
    
    def display(self):
        tab = widgets.Tab()
        tab_contents = [
            widgets.VBox([self.restaurant_name, self.city, self.cuisine_type]),
            widgets.VBox([self.price_range]),
            widgets.VBox([self.regions]),
            widgets.VBox([self.credit_cards_grid]),
            widgets.VBox([self.facilities])
        ]
        tab.children = tab_contents
        tab.set_title(0, 'General Criteria')
        tab.set_title(1, 'Price')
        tab.set_title(2, 'Region')
        tab.set_title(3, 'Accepted Cards')
        tab.set_title(4, 'Offered Services')

        display(tab, self.search_button, self.output)

    def get_values(self):
        return {
            'restaurantName': self.restaurant_name.value,
            'city': self.city.value,
            'cuisineType': self.cuisine_type.value,
            'priceRange': self.price_range.value,
            'regions': list(self.regions.value),
            'creditCards': [checkbox.description for checkbox in self.credit_card_checkboxes if checkbox.value],
            'facilities': list(self.facilities.value)
        }

    def on_search_button_clicked(self, b):
        with self.output:
            self.output.clear_output()
            values = self.get_values()
            print("Collected Values:")
            for key, value in values.items():
                print(f"{key}: {value}")

# %% [markdown]
# The following cell performs **pre-processing** on the restaurant dataset:
#
# - **Stopwords**: Defines and combines Italian and English stopwords.
# - **Cleaning Functions**:
#   - **`clean_text_with_stopwords`**: Cleans text by removing stopwords and special characters.
#   - **`clean_text_basic`**: Cleans text while keeping all words (used for the `city` field).
# - **Cleaning Application**:
#   - Creates normalized (`_clean`) versions of the `restaurantName`, `cuisineType`, and `city` fields.
# - **Decoding**: Converts `facilitiesServices` and `creditCards` fields into Python lists.
# - **Output**: Displays a preview of the pre-processed DataFrame.

# %%
# Italian and English stopwords
stopwords_italian = set([
    'il', 'lo', 'la', 'i', 'gli', 'le', 'un', 'una', 'del', 'della', 'dello',
    'dei', 'di', 'a', 'ai', 'al', 'allo', 'alle', 'degli', 'd', 'da', 'dal',
    'dallo', 'in', 'nel', 'nello', 'su', 'sul', 'sullo', 'con', 'per', 'tra',
    'fra', 'e'
])
stopwords_english = set(stopwords.words('english'))
stopwords_combined = stopwords_italian.union(stopwords_english)

# Removing stopwords
def clean_text_with_stopwords(text):
    if pd.isna(text):
        return ''
    text = text.lower().strip()
    text = re.sub(r"[^\w\s']", '', text) 
    words = text.split()
    words = [word for word in words if word not in stopwords_combined]  
    return ' '.join(words)

# Basic clean without removing stopwords
def clean_text_basic(text):
    if pd.isna(text):
        return ''
    return text.strip().lower()

#Read CSV
file_path = r'C:\Users\matti\Documents\ADM\HW3\merged_output.csv'
df = pd.read_csv(file_path)


df['restaurantName_clean'] = df['restaurantName'].apply(clean_text_with_stopwords)
df['cuisineType_clean'] = df['cuisineType'].apply(clean_text_with_stopwords)
# For the city field, we do not remove stopwords but apply basic cleaning, as removing them could affect the meaning of the city name.
df['city_clean'] = df['city'].apply(clean_text_basic)

df['facilitiesServices_clean'] = df['facilitiesServices'].apply(lambda x: eval(x) if pd.notna(x) else [])
df['creditCards_clean'] = df['creditCards'].apply(lambda x: eval(x) if pd.notna(x) else [])

print("Pre_processed data:")
display(df[['restaurantName','restaurantName_clean', 'city','city_clean', 'cuisineType','cuisineType_clean', 'facilitiesServices','facilitiesServices_clean', 'creditCards','creditCards_clean','priceRange']].head())
# Out:
# Pre_processed data:
#   restaurantName restaurantName_clean                     city  \
# 0  Burro & Alici          burro alici                  Marotta
# 1          Oishi                oishi                   Teramo
# 2        Uliassi              uliassi               Senigallia
# 3    Oberlechner          oberlechner                   Algund
# 4  Ai Gondolieri           gondolieri   sestiere Dorsoduro 366
#
#                city_clean                        cuisineType  \
# 0                 marotta           Seafood, Classic Cuisine
# 1                  teramo                   Japanese, Fusion
# 2              senigallia                  Creative, Seafood
# 3                  algund  Regional Cuisine, Classic Cuisine
# 4  sestiere dorsoduro 366      Venetian, Traditional Cuisine
#
#                   cuisineType_clean  \
# 0           seafood classic cuisine
# 1                   japanese fusion
# 2                  creative seafood
# 3  regional cuisine classic cuisine
# 4      venetian traditional cuisine
#
#                                   facilitiesServices  \
# 0                                        ['Terrace']
# 1  ['Air conditioning', 'Counter dining', 'Terrace']
# 2  ['Air conditioning', 'Great view', 'Interestin...
# 3  ['Car park', 'Garden or park', 'Great view', '...
# 4                               ['Air conditioning']
#
#                             facilitiesServices_clean  \
# 0                                          [Terrace]
# 1        [Air conditioning, Counter dining, Terrace]
# 2  [Air conditioning, Great view, Interesting win...
# 3    [Car park, Garden or park, Great view, Terrace]
# 4                                 [Air conditioning]
#
#                                          creditCards  \
# 0                     ['Amex', 'Mastercard', 'Visa']
# 1  ['Amex', 'Unionpay', 'Dinersclub', 'Discover',...
# 2       ['Amex', 'Dinersclub', 'Mastercard', 'Visa']
# 3                             ['Mastercard', 'Visa']
# 4      ['Amex', 'Maestrocard', 'Mastercard', 'Visa']
#
#                                    creditCards_clean priceRange
# 0                           [Amex, Mastercard, Visa]         €€
# 1  [Amex, Unionpay, Dinersclub, Discover, Jcb, Ma...         €€
# 2               [Amex, Dinersclub, Mastercard, Visa]       €€€€
# 3                                 [Mastercard, Visa]         €€
# 4              [Amex, Maestrocard, Mastercard, Visa]        €€€

# %%
# Function to create an inverted index for a specific field
def build_inverted_index(df, column):
    inverted_index = defaultdict(set)  
    for idx, value in df[column].items():
        terms = value.split() 
        for term in terms:
            inverted_index[term].add(idx) 
    return inverted_index

# Creation of inverted indices
restaurant_name_index = build_inverted_index(df, 'restaurantName_clean')
city_index = build_inverted_index(df, 'city_clean')
cuisine_type_index = build_inverted_index(df, 'cuisineType_clean')

print("Indice invertito per restaurantName (parziale):")
for term, indices in list(restaurant_name_index.items()):
    print(f"'{term}': {indices}")
# Out:
# Indice invertito per restaurantName (parziale):
# 'burro': {0}
# 'alici': {0, 1390}
# 'oishi': {1}
# 'uliassi': {2}
# 'oberlechner': {3}
# 'gondolieri': {4}
# 'locanda': {1152, 1028, 5, 645, 392, 649, 1674, 1419, 1548, 655, 1552, 273, 20, 1815, 1948, 1823, 803, 1957, 1191, 683, 1838, 559, 53, 1590, 1591, 1465, 1978, 1468, 574, 1859, 196, 198, 327, 845, 719, 464, 209, 1103, 1361, 1487, 213, 726, 1618, 88, 1243, 732, 1116, 866, 994, 1890, 614, 615, 1128, 745, 1001, 1384, 1388, 749, 1134, 367, 496, 241, 1775, 628, 887, 1274, 892}
# 'belvedere': {578, 1076, 5}
# 'tenuta': {433, 1949, 6}
# 'gallo': {166, 934, 6, 1395, 122, 894}
# 'fico': {7}
# 'trentacareghe': {7}
# 'trattoria': {1923, 1019, 8, 906, 654, 400, 1298, 22, 1303, 24, 1176, 922, 1178, 1690, 1820, 1944, 672, 800, 1575, 1194, 555, 301, 1457, 826, 187, 188, 1596, 1853, 1980, 192, 965, 583, 1483, 593, 1617, 1369, 90, 1754, 861, 1248, 1377, 228, 1510, 231, 635, 1641, 234, 491, 874, 493, 621, 1768, 1773, 1137, 1777, 1395, 1651, 122, 507, 764}
# 'parco': {8, 582}
# 'selvatico': {9}
# 'l'oste': {10, 1747, 452}
# 'scuro': {10, 1963}
# 'bistrot': {1664, 387, 1798, 1416, 11, 1547, 534, 1048, 671, 1323, 1196, 819, 1974, 705, 1862, 1223, 467, 598, 859, 103, 107, 371, 1527, 762, 1790}
# 'donatella': {11}
# 'vicolo': {1064, 1483, 12}
# 'colombina': {12}
# 'san': {1419, 13, 526, 1174, 1699, 293, 181, 1589, 1594, 1347, 196, 1231, 1236, 726, 471, 1504, 1764, 622, 1006, 756, 634, 1146, 509, 126}
# 'marco': {545, 938, 1507, 13}
# 'corte': {1660, 1345, 1729, 1062, 41, 1611, 524, 14, 1170, 1108, 56, 348}
# 'federiciana': {14}
# 'l'800': {15}
# 'terme': {16}
# 'lido': {17}
# '84': {17}
# 'ciau': {18}
# 'tornavento': {18}
# 'cecco': {19}
# 'mariella': {20}
# 'phi': {21}
# 'restaurant': {1285, 390, 903, 1421, 1550, 1555, 21, 1175, 1433, 1054, 545, 1442, 295, 1576, 1065, 1070, 433, 435, 823, 569, 1340, 957, 1217, 964, 325, 1094, 1479, 1480, 715, 332, 1100, 334, 1101, 1869, 1491, 1366, 474, 1499, 1883, 1245, 1509, 743, 360, 1264, 248, 1913}
# 'giancarlo': {21}
# 'morelli': {205, 1012, 21}
# 'fortuna': {937, 22}
# 'società': {23}
# 'milano': {1063, 872, 1069, 23, 346, 316}
# 'masenini': {24}
# 'une': {25}
# 'magnolia': {1353, 26}
# 'giannino': {27, 639}
# 'l'angolo': {27, 1917}
# 'd'abruzzo': {1970, 27, 1917}
# 'marcandole': {28}
# 'soul': {29}
# 'fish': {1184, 29, 167}
# 'baita': {1824, 1210, 30}
# 'fraina': {30}
# 'borgo': {835, 504, 712, 431, 1551, 437, 53, 1174, 440, 31}
# 'poscolle': {31}
# 'emilio': {32}
# 'innesti': {33}
# 'romani': {34, 895}
# 'l'osteria': {35, 590, 1109, 1045, 312}
# 'castellazzo': {35}
# 'aqua': {36, 268}
# 'crua': {36}
# 'charleston': {37}
# 'filanda': {690, 38, 271}
# 'villa': {1024, 1666, 1301, 1951, 39, 936, 940, 302, 176, 433, 1336, 1600, 199, 1246, 353, 1257, 1515, 1143, 761, 1915}
# 'arcadio': {39}
# 'osteria': {1537, 1029, 518, 1542, 1060, 1062, 40, 1578, 1579, 562, 58, 1082, 1594, 1087, 1599, 1095, 1097, 81, 594, 86, 87, 1110, 95, 613, 1637, 1639, 1640, 117, 121, 1657, 1659, 638, 132, 133, 1161, 139, 1678, 660, 667, 159, 674, 1186, 676, 166, 678, 1712, 689, 709, 1734, 712, 721, 212, 1749, 1750, 727, 728, 217, 730, 731, 1241, 1252, 1253, 232, 1259, 749, 757, 251, 1277, 258, 1797, 1289, 1290, 779, 269, 1295, 1807, 1299, 1817, 1306, 795, 804, 1316, 808, 1836, 1327, 1330, 310, 824, 825, 827, 1856, 834, 836, 1865, 844, 1360, 1873, 1879, 347, 863, 364, 1901, 1905, 1914, 1916, 1409, 1922, 389, 1927, 1417, 914, 916, 1435, 928, 929, 427, 1459, 436, 437, 949, 440, 458, 1484, 461, 976, 977, 468, 985, 1497, 483, 996, 1507, 486, 1508, 490, 1002, 1008, 497, 1012, 1524, 1016, 505, 1530, 1020}
# 'logge': {40, 1788}
# 'visconti': {41}
# 'cuculia': {42}
# 'ercole': {43}
# 'stube': {899, 44, 1872, 439, 734}
# 'ladina': {44, 783}
# 'dolia': {45}
# 'gaeta': {45}
# 'tino': {46}
# 'punto': {47}
# 'g': {47}
# 'capriccio': {48, 1046}
# 'alla': {834, 1795, 1859, 1096, 173, 1358, 1773, 49, 1042, 244, 309, 1108, 56, 89, 1596}
# 'pace': {49, 1885}
# 'kosmo': {50}
# 'taste': {50}
# 'mountain': {50}
# 'spin': {51}
# 'ristoranteenoteca': {51}
# 'apollinare': {52}
# 'mirabelle': {54}
# 'aimo': {546, 1972, 55}
# 'nadia': {546, 1972, 1702, 55}
# 'bistro': {55}
# 'stefano': {56, 1519}
# 'paganini': {56}
# 'alfieri': {56}
# 'lord': {1592, 57}
# 'nelson': {57}
# 'de': {1255, 1384, 1515, 1370, 462, 1790, 1235, 917, 86, 1847, 953, 58, 1403, 702}
# 'börg': {58}
# 'macelleria': {218, 59, 1092}
# 'motta': {59}
# 'terra': {60, 1781}
# 'magic': {60}
# 'place': {60, 935}
# 'belbo': {61}
# 'bardon': {61}
# 'entrà': {62}
# 'flurin': {63}
# 'andrea': {64, 128, 803, 164, 541, 510}
# 'larossa': {64}
# 'atto': {65}
# 'vito': {65}
# 'mollica': {65}
# 'famiglia': {66}
# 'rana': {66}
# 'atelier': {67, 852}
# 'cavallino': {1544, 1201, 1122, 68}
# 'bianco': {68}
# 'frosio': {69}
# 'terrazza': {451, 643, 70, 1688, 1904, 1233, 1053, 1841, 216, 476, 1021}
# 'bosquet': {70}
# 'poggio': {399, 71}
# 'vini': {72, 285, 1238}
# 'gigio': {72}
# 'palagio': {73}
# 'scudiero': {74}
# 'marina': {1799, 489, 75, 590, 1711}
# 'nettuno': {75}
# 'enoteca': {384, 1735, 76, 1037, 1462, 221, 126, 735}
# 'torre': {76, 1911, 1232, 497, 151, 1627, 1022}
# 'forentum': {77}
# 'enrico': {234, 1036, 78, 1823}
# 'bartolini': {1316, 234, 1036, 78, 1841, 87, 827, 1823}
# 'mudec': {78}
# 'lorelei': {79}
# 'nando': {80, 483}
# 'borro': {81}
# 'l'ambasciata': {82}
# 'due': {1828, 1863, 168, 594, 83, 1394, 1178, 1565, 1662}
# 'colombe': {83, 631}
# 'palazzaccio': {84}
# 'rosa': {1377, 1071, 1424, 85, 505, 1755}
# 'venti': {85}
# 'l'umbreleèr': {86}
# 'viola': {88, 1642}
# 'laguna': {89}
# 'vedova': {89}
# 'raddi': {89}
# 'ceriati': {90}
# 'feel': {91}
# 'como': {91}
# 'sapereta': {92}
# 'sa': {868, 1942, 1660, 93, 1630}
# 'domu': {93}
# 'sarda': {93}
# 'cucoma': {94}
# 'teatro': {618, 980, 95}
# 'el': {96, 1091, 455, 1877, 214, 1180}
# 'molin': {96, 406}
# 'pescatore': {97, 642, 988}
# 'omar': {98}
# 'etra': {99}
# 'gino': {100}
# 'sorbillo': {100}
# 'particolare': {101}
# 'siena': {101}
# 'agorà': {102}
# 'cannavacciuolo': {1732, 103, 974, 1040, 284}
# 'hosteria': {104, 304, 1104, 374, 920}
# 'giusti': {104}
# 'campocori': {105}
# 'li': {106, 1635, 1570, 1183}
# 'somari': {106}
# 'lanzani': {107}
# 'bottega': {736, 773, 1573, 1321, 938, 107, 533}
# 'piazza': {1017, 108}
# 'duomo': {760, 913, 108, 1564}
# 'comi': {109}
# '107': {109}
# 'cucina': {391, 912, 1553, 658, 1936, 285, 1059, 932, 1315, 1597, 322, 208, 338, 1236, 1238, 345, 477, 1638, 1767, 1772, 110}
# 'cereda': {110}
# 'trippini': {111}
# 'soltojo': {112}
# 'luca's': {113}
# 'paulo': {113}
# 'airaudo': {113}
# 'veneziano': {114}
# 'aquadulcis': {115}
# 'capanna': {116}
# 'eraclio': {116}
# 'gigianca': {117}
# 'joia': {118}
# 'acquerello': {119}
# 'monastero': {120}
# 'marchese': {121, 1484}
# 'mercato': {121, 1484, 1020}
# 'liquori': {121, 1484}
# 'antica': {1028, 389, 1286, 1542, 779, 654, 271, 1295, 1552, 1807, 1936, 1685, 1459, 1461, 1591, 444, 1087, 192, 1092, 965, 583, 1611, 716, 1750, 217, 731, 861, 1119, 615, 874, 367, 1905, 1395, 505, 122, 1019}
# '1909': {122}
# 'bites': {123}
# 'cambio': {124, 1502}
# 'baccanti': {740, 125}
# 'nicola': {126}
# 'casa': {777, 1808, 915, 1428, 150, 1949, 1182, 1968, 691, 1077, 695, 1208, 1212, 1598, 1473, 1735, 586, 1869, 1744, 979, 369, 885, 889, 127}
# 'leali': {127}
# 'sapori': {128, 552, 493, 1431}
# 'montani': {128}
# 'cuoco': {129}
# 'bordo': {129}
# 'contesto': {130}
# 'alimentare': {130}
# 'sale': {337, 131}
# 'grosso': {131}
# 'chiocciola': {1849, 132}
# 'zanchetti': {133}
# 'santa': {600, 590, 1244, 134}
# 'teresa': {288, 134}
# 'cipresso': {135}
# 'cioni': {135}
# 'prato': {136}
# 'gaio': {136}
# 'nicchia': {137}
# 'unterwirt': {138}
# 'l'abbiccì': {139}
# 'innocenti': {140, 780}
# 'evasioni': {140}
# 'rosita': {141}
# 'bacco': {865, 1958, 142, 1234, 1622}
# 'taverna': {550, 393, 713, 1964, 174, 143, 1593, 626, 883, 1689, 1205, 1622, 1880, 313, 1595, 1631}
# 'kerkira': {143}
# 'quattro': {144, 822, 566}
# 'gigli': {144}
# 'lampare': {145}
# 'fortino': {145}
# 'vivace': {146}
# 'boccadoro': {147}
# 'cip's': {148}
# 'club': {148, 1103}
# 'antiche': {1218, 539, 149, 1011}
# 'carampane': {149}
# 'vicina': {150}
# 'vez': {152}
# 'clandestino': {153}
# 'susci': {153}
# 'bar': {153, 627, 927}
# 'zafferano': {154}
# 'quellenhof': {155}
# 'gourmetstube': {584, 155}
# '1897': {155}
# 'loro': {156}
# 'gellius': {157}
# 'satricvm': {158}
# 'expanificio': {159}
# 'daniela': {160}
# 'basilisco': {161}
# 'finger's': {162}
# 'garden': {296, 162, 1971, 1494}
# 'fausto': {163, 395}
# 'dissapore': {164}
# 'catalano': {164}
# 'iyo': {165, 1751}
# 'volpe': {166}
# 'bob': {167}
# 'cook': {1039, 167}
# 'pini': {168}
# 'accademia': {169}
# 'ristorante': {1153, 1158, 1035, 1048, 416, 290, 169, 938, 1535, 1707, 942, 306, 311, 1850, 1083, 1723, 701, 959, 963, 335, 1255, 1513, 1258, 747, 236, 1260, 1646, 624, 383}
# 'orlando': {170}
# 'portici': {171}
# 'ristofante': {172}
# 'fassa': {173}
# 'dell'oca': {1016, 174}
# 'battaglino': {175}
# 'salina': {176}
# 'pipero': {177}
# 'roma': {1832, 177, 610, 1756}
# 'pulejo': {178}
# 'vineria': {898, 179}
# 'modì': {179, 703}
# 'sora': {180}
# 'maria': {180}
# 'arcangelo': {180}
# 'podere': {578, 652, 181}
# 'faustino': {181}
# 's'andira': {182}
# 'tre': {1313, 423, 585, 362, 1934, 887, 1137, 631, 183}
# 'noci': {183}
# 'carroponte': {184}
# 'parma': {185}
# 'rotta': {185}
# 'tenne': {186}
# 'lodges': {186}
# 'probo': {187}
# 'colonna': {620, 188}
# 'porcino': {189}
# 'contraste': {190}
# 'galeone': {191}
# 'grotta': {192}
# '1918': {192}
# 'marc': {193}
# 'lanteri': {193}
# 'kohaku': {194}
# 'salsedine367': {195}
# 'martino': {1699, 196, 1764, 756, 953, 927}
# 'agli': {1348, 197}
# 'amici': {1348, 197}
# 'piero': {198}
# 'tiboldi': {199}
# 'cibrèo': {200, 555}
# 'vignamare': {201}
# 'lunasia': {202}
# 'storie': {203}
# 'd'amore': {203}
# 'codole': {204}
# 'pomiroeu': {206}
# 'kuccagna': {207}
# 'tradizione': {208}
# 'casalinga': {208}
# 'falco': {209, 1274}
# 'alfonso': {210, 509}
# '1890': {210, 509}
# 'scola': {211}
# 'platzegg': {212}
# 'condo': {213}
# 'gato': {214}
# 'pifferi': {215}
# 'fiorella': {216}
# 'moirago': {217}
# 'damini': {218}
# 'affini': {218}
# 'peppe': {219}
# 'kirchsteiger': {220}
# 'duca': {221}
# 'da_mó': {222}
# 'lazzaro': {223}
# '1915': {223}
# 'sedicesimo': {224}
# 'secolo': {224}
# 'vino': {225, 1315, 1597, 1772, 1808, 338, 477}
# 'buono': {225, 691}
# 'riccio': {226, 1285}
# 'badessa': {227}
# 'porteri': {228}
# 'glass': {229}
# 'hostaria': {385, 547, 229, 1317, 1064, 1642, 1803, 1453, 527, 1042, 980, 1015, 1049}
# 'fratanza': {230}
# 'coronate': {231}
# 'magona': {232}
# 'castello': {233, 1355, 1593, 1402, 955}
# 'malvezzi': {233}
# 'schöneck': {235}
# 'peter': {236}
# 'brunel': {236}
# 'gourmet': {768, 1574, 1481, 236, 524, 1619, 1047, 439, 1848, 377, 1755}
# 'colline': {809, 237}
# 'ciociare': {237}
# 'zur': {1472, 238}
# 'rose': {781, 238, 1798}
# 'cala': {239}
# 'luna': {1860, 645, 684, 812, 239}
# 'cementine': {240}
# 'notaio': {241}
# 'madernassa': {242}
# 'tuorlo': {243}
# 'lanterna': {709, 900, 244, 309}
# 'vintage': {245}
# '1997': {245}
# 'benedikto': {246}
# 'carne': {247}
# 'spirito': {1167, 247}
# 'kandoo': {248}
# 'nippon': {248}
# 'masseria': {249, 810}
# 'oseleta': {250}
# 'granaio': {251}
# 'posta': {1900, 906, 252, 1925}
# 'bove's': {253}
# 'cibus': {254}
# 'colonne': {1870, 366, 255}
# 'zelo': {256}
# 'ippogrifo': {257}
# 'numero': {1537, 258}
# '2': {258}
# 'acqua': {1888, 1129, 314, 259}
# 'pazza': {1888, 259}
# 'tavola': {1752, 260, 629}
# 'rossa': {1162, 260, 1860}
# 'vincenzo': {724, 260}
# 'guarino': {260}
# 'stefenelli': {261}
# 'desk': {261}
# 'patio': {1720, 262}
# 'santamonica': {263}
# 'crotasc': {264}
# 'contrasto': {265}
# 'chichibio': {266}
# 'cascinalenuovo': {267}
# 'solita': {269}
# 'zuppa': {269}
# 'madama': {270, 542}
# 'vigna': {270}
# 'qb': {272}
# 'duepuntozero': {272}
# ''800': {273}
# 'radici': {1095, 1130, 528, 274, 1815}
# 'cile's': {275}
# 'qualia': {276}
# 'petit': {277}
# 'bellevue': {277}
# 'terramadre': {278}
# 'ichikawa': {279}
# 'coccinella': {280}
# 'retrogusto': {281}
# 'walser': {282}
# 'schtuba': {282}
# 'mikele': {283}
# 'lake': {425, 284}
# 'perbacco': {285, 319}
# 'laghetto': {286}
# 'veranda': {1436, 516, 365, 287}
# 'color': {287}
# 'giorgio': {1504, 289, 1347}
# 'flora': {289}
# 'alain': {290}
# 'ducasse': {290}
# 'napoli': {290}
# 'zass': {291}
# 'magnagallo': {292}
# 'baretto': {386, 293}
# 'vigilio': {293}
# 'muraglia': {294}
# 'conchiglia': {1466, 405, 294}
# 'd'oro': {1314, 294, 687, 304, 1873, 1845, 856, 1466, 860, 1085, 574}
# 'contaminazioni': {295}
# 'roof': {296, 1494}
# 'moro': {1634, 388, 297, 1289, 373, 949}
# 'alto': {298}
# 'cascina': {752, 299, 1749, 1710}
# 'vittoria': {299, 1830}
# 'mare': {1152, 1528, 779, 300, 1105, 339, 340, 1781, 1910, 727, 1112, 1851, 1727}
# 'glisenti': {301}
# 'fiordaliso': {302}
# 'mardivino': {303}
# 'grappolo': {304, 313}
# 'kuppelrain': {305}
# 'filia': {306}
# 'santi': {362, 307}
# 'leoni': {307, 1923}
# 'mistral': {308}
# 'miro': {309}
# 'billis': {310}
# 'mascì': {311}
# 'trippa': {312, 1731}
# 'blu': {313, 1426, 1582, 911}
# 'barbieri': {315}
# 'posto': {316, 1327}
# 'galileo': {317}
# 'caino': {318}
# 'pievano': {320}
# 'malò': {322}
# 'miscelazione': {322}
# 'vespasia': {323}
# 'moscatello': {324}
# 'muliner': {324}
# 'trippi': {326}
# 'gesù': {327}
# 'vecchio': {327, 712, 1575, 465, 434, 1654, 607}
# 'rossellinis': {328}
# 'stella': {329, 574, 609}
# 'ansitz': {330, 895}
# 'steinbock': {330}
# 'vögele': {331}
# 'j': {332}
# 'contemporary': {569, 332}
# 'japanese': {744, 332}
# 'cielo': {333, 1334}
# 'gagini': {334}
# 'matteo': {1302, 335}
# 'pantagruele': {336}
# 'menabò': {338}
# 'romolo': {339}
# 'dav': {340}
# 'cicale': {341, 750}
# 'tonino': {342}
# 'marixx': {343}
# 'cupole': {344}
# 'frigoriferi': {345}
# 'milanesi': {345}
# 'antico': {383, 1172, 1784, 347, 1535}
# 'brolo': {347}
# 'sconta': {348}
# 'zeb': {349}
# 'd'o': {350}
# 'alpinn': {351}
# 'ca'': {352, 1634, 1830, 1481, 554, 363, 396, 1907}
# 'profeta': {352}
# 'baroni': {353}
# 'aciniello': {354}
# 'gratschwirt': {355}
# 'viole': {356}
# 'palazzo': {1505, 357, 459, 1965, 1181}
# 'utini': {357}
# 'castel': {1197, 358}
# 'fine': {1420, 358}
# 'dining': {580, 358}
# '5': {831, 359}
# 'campanili': {975, 359}
# 'porta': {360, 1485, 1461}
# 'mecenate': {361}
# 'concettina': {362}
# '7': {363, 1215}
# 'taviani': {364}
# 'cervo': {1938, 367}
# 'landgasthof': {367}
# 'zum': {485, 367}
# 'hirschen': {367}
# 'macine': {368}
# 'coppelle': {369}
# 'wood': {370}
# 'altatto': {371}
# 'delicato': {372}
# 'cave': {374}
# 'cantù': {1468, 374}
# 'ö': {375}
# 'vittorio': {1932, 375}
# 'trota': {376}
# 'maison': {377, 714, 1404, 1370}
# 'du': {377}
# 'sottosopra': {378}
# 'oscar': {379, 982}
# 'valli': {380}
# 'lanzo': {380}
# 'konnubio': {381}
# 'portanova': {382}
# 'forassiepi': {383}
# 'buttrio': {384}
# 'uva': {385}
# 'rara': {385}
# 'gallery': {387}
# 'contemporaneo': {387}
# 'vescovo': {388}
# 'cera': {389}
# 'musa': {390}
# 'rooftop': {1332, 390}
# 'terrace': {390}
# 'materia': {1967, 602, 391}
# 'spazio': {391}
# 'pincelli': {392}
# 'cialoma': {393}
# 'blaue': {394}
# 'traube': {394}
# 'matilde': {1729, 396}
# 'aldìvino': {397}
# 'menarosti': {398}
# 'rosso': {1807, 399, 1204, 1782, 797}
# 'via': {400, 672}
# 'serra': {400, 1585}
# 'quartina': {401}
# 'piave': {402}
# 'fre': {403}
# 'darmagi': {404}
# 'vecio': {1652, 406}
# 'anastasia': {407}
# 'nugolo': {408}
# 'bon': {409}
# 'wei': {409}
# 'harry's': {410}
# 'piccolo': {1188, 1592, 788, 472, 410}
# 'belé': {411}
# 'johannesstube': {412}
# 'pagliaccio': {413}
# 'sponda': {414}
# 'altavilla': {415}
# '1500': {416}
# 'loewengrube': {417}
# 'labirinto': {418}
# 'franceschetta': {419}
# '58': {626, 419}
# 'trita': {420}
# 'pepe': {1626, 420, 1935}
# 'l'acciuga': {421, 1446}
# 'vitis': {422}
# 'noghere': {423}
# 'dama': {424, 1340}
# 'senso': {425}
# 'alfio': {425, 886}
# 'ghezzi': {425, 886}
# 'garda': {425}
# 'pavone': {426, 1317}
# 'ardenga': {427}
# 'martinatica': {428}
# 'ifame': {429}
# 'donevandro': {430}
# 'spoltino': {431}
# 'januarius': {432}
# 'josè': {433}
# 'guerra': {433}
# 'convento': {1968, 434}
# 'italo': {435}
# 'bassi': {435}
# 'confusion': {435}
# 'acquarol': {436}
# 'ronche': {437}
# 'boccondivino': {438}
# 'turacciolo': {441}
# 'gallina': {442}
# 'circolino': {443}
# 'corona': {444}
# 'reale': {641, 444}
# 'malga': {1954, 445}
# 'roncac': {445}
# 'rivale': {947, 446}
# 'città': {446, 750}
# 'imperialino': {447}
# 'sette': {448, 1537}
# 'consoli': {448}
# 'olona': {449}
# 'venanzio': {449}
# '1922': {449}
# 'consorzio': {450}
# 'gallia': {451}
# 'sacrestano': {452}
# 'giacomo': {453}
# 'regina': {454}
# 'lucia': {533, 454, 663}
# 'filò': {455}
# 'teresita': {456}
# 'giardino': {456, 1004, 818, 1554, 890}
# 'mari': {456}
# 'cavallo': {457}
# 'scosso': {457}
# 'borsò': {458}
# 'gambrinus': {458, 582}
# 'salvo': {460, 1783}
# 'cacciatori': {1001, 1490, 1802, 460}
# 'fernanda': {461}
# 'gustibus': {702, 462}
# 'l'ortone': {463}
# 'gulfi': {464}
# 'ristoro': {465}
# 'santo': {466, 1167}
# 'bevitore': {466}
# 'essenza': {1474, 467}
# 'magiargè': {468}
# 'contemporanea': {929, 1060, 1095, 468, 1435, 1817, 1369, 667, 1277}
# 'pernambucco': {469}
# 'pellicano': {470}
# 'gunè': {471}
# 'frediano': {471}
# 'nana': {472}
# 'bistrò': {472, 1007}
# 'casolare': {473}
# 'segreti': {824, 473}
# 'kanton': {474}
# 'vecchia': {1799, 653, 1139, 475, 795}
# 'malcesine': {475}
# 'ape': {477}
# 'ventuno1': {478}
# 'dispensa': {1747, 1615, 479}
# 'armatore': {479}
# 'sadler': {480, 1250, 1117}
# 'duo': {481, 1260, 1324}
# 'walter': {482}
# 'redaelli': {482}
# 'alessandro': {1402, 484}
# 'feo': {484}
# 'löwen': {485}
# 'l'archivolto': {486}
# 'nostrale': {486}
# 'pashà': {487}
# 'lou': {488}
# 'ressignon': {488}
# 'guà': {490}
# 'almondo': {491}
# 'retrobottega': {492}
# 'antichi': {552, 493, 1431}
# 'oberwirt': {494}
# 'anima': {495}
# 'margon': {496}
# 'amo': {498, 1196}
# 'hyle': {499}
# 'residenza': {500}
# 'lago': {1801, 747, 1739, 1328, 947, 500}
# 'moi': {1449, 501}
# 'president': {502}
# 'altriménti': {503}
# 'nonna': {505, 1123, 1116}
# 'aroma': {506}
# 'battibecco': {507}
# 'zunica': {508}
# '1880': {508}
# 'barbato': {509}
# 'bagatto': {733, 863, 511}
# 'saur': {512}
# 'grop': {513}
# 'rodella': {514}
# 'sosta': {1648, 515}
# 'ottone': {515}
# 'iii': {515}
# 'luge': {517}
# '1861': {518}
# 'prezioso': {519}
# 'aquariva': {520}
# 'l'antica': {521}
# 'pizzeria': {521, 1505}
# 'michele': {521, 1403, 726, 526}
# 'unforgettable': {522}
# 'tilia': {523}
# 'cetaria': {525}
# 'bricai': {527}
# 'braja': {529}
# 'ridotto': {530}
# 'giano': {531}
# 'lucio': {532}
# 'extra': {535}
# 'beccherie': {536}
# 'acaja': {537}
# 'presidente': {538}
# 'mura': {539}
# 'tempo': {1587, 540, 1836}
# 'nuovo': {1176, 540}
# 'aprea': {541}
# 'piola': {542}
# 'chicco': {543}
# 'grano': {1626, 846, 543}
# 'cesare': {544}
# 'martini': {545}
# 'luogo': {546}
# 'franz': {547}
# 'quintogusto': {548}
# 'repubblica': {549}
# 'perno': {549}
# 'rovita': {550}
# 'kro': {551}
# 'oasis': {552}
# 'camin': {553}
# 'd'frara': {554}
# 'cibrèino': {555}
# 'marchesi': {556}
# 'noemi': {557}
# 'caffè': {1798, 1323, 1421, 558, 561, 1081, 1150}
# 'grande': {1865, 558, 1711}
# 'colonnello': {559}
# 'maré': {560}
# 'crepa': {561}
# 'passignano': {562}
# 'braseria': {563}
# 'capogiro': {564}
# 'eggentaler': {565}
# 'passi': {566}
# 'lipadusa': {567}
# 'ada': {568}
# 'førma': {569}
# 'cedro': {570, 605}
# 'contrada': {722, 571}
# 'maso': {612, 572, 1759}
# 'palù': {572}
# 'rosina': {573}
# 'signum': {575}
# 'manuelina': {576}
# 'giglio': {577, 845}
# 'tuscany': {578}
# 'bramea': {579}
# 'aede': {580}
# 'wines': {580}
# 'arnaldo': {581}
# 'clinica': {581}
# 'gastronomica': {581}
# 'toppa': {583}
# 'einhorn': {584}
# 'scalini': {585}
# 'coloni': {586}
# 'ad': {587}
# 'astra': {587}
# 'l'acquario': {588}
# 'notizia': {589}
# '53': {1333, 589, 1103}
# 'lorenzo': {1231, 1419, 1516, 591}
# 'idylio': {592}
# 'apreda': {592}
# 'pierre': {593, 786}
# 'sartoriale': {593}
# 'spade': {594}
# 'josto': {595}
# 'sud': {596}
# 'foresta': {625, 597}
# 'mater': {1382, 1603, 598}
# 'villetta': {836, 599}
# 'annessa': {599}
# 'capo': {600}
# 'chiara': {600}
# 'radimare': {601}
# 'ipalici': {603}
# 'hydra': {604}
# 'campo': {637, 605}
# 'crub': {606}
# 'porto': {1938, 607}
# 'lokanda': {608}
# 'devetak': {608}
# 'd'italia': {609}
# 'orma': {610}
# 'l'olivo': {611}
# 'runchhof': {612}
# 'pietro': {613}
# 'molino': {614}
# 'sesto': {615}
# 'bibe': {616}
# 'pacifico': {617}
# 'flavio': {618}
# 'fabrizio': {618}
# 'chiaroscuro': {619}
# 'antonello': {620}
# 'labico': {620}
# 'campagna': {621}
# 'quintino': {622}
# 'resort': {622}
# 'lofficina': {623}
# 'niko': {624, 1258}
# 'romito': {624, 1258}
# 'à': {627}
# 'fromage': {627}
# 'solagna': {628}
# 'remulass': {630}
# 'moebius': {632}
# 'sperimentale': {632}
# 'enotavola': {633}
# 'tommaso': {634}
# '10': {634}
# 'marino': {1131, 635, 1495}
# 'gelsomina': {636}
# 'drago': {637}
# '36': {638}
# '1899': {752, 639}
# 'papavero': {640}
# 'danieli': {643}
# 'federico': {644}
# 'ii': {644}
# 'romano': {646}
# 'gregorio': {647}
# 'mirepuà': {648}
# 'food': {648, 1610, 700}
# 'lab': {648}
# 'martinelli': {649}
# 'cappero': {650}
# 'soho': {651}
# '39': {652}
# 'sorni': {653}
# 'cattivelli': {654}
# 'mammì': {655}
# 'gigetto': {656}
# 'l'accanto': {657}
# 'de'': {1696, 658, 914}
# 'mibabbo': {658}
# 'guidoristorante': {659}
# 'origano': {660}
# 'sottovoce': {661}
# 'krèsios': {662}
# 'sogno': {664, 1733}
# 'camana': {665}
# 'veglia': {665}
# 'patauner': {666}
# 'bis': {667}
# 'italiana': {1638, 667, 1262}
# 'marelet': {668}
# 'rovello': {669}
# '18': {669}
# 'palmerino': {670}
# 'bacalà': {670}
# 'sandrigo': {670}
# 'porteghi': {671}
# 'vai': {672}
# 'berton': {673}
# 'bakaré': {674}
# 'rosselli': {675}
# '77': {675}
# 'ophis': {676}
# 'urubamba': {677}
# 'tana': {917, 678, 1047}
# 'oberraindlhof': {679}
# 'pepenero': {680}
# 'rima': {681}
# 'eea': {682}
# 'altobelli': {683}
# 'io': {1027, 684, 1599}
# 'fàula': {685}
# 'quintilio': {686}
# 'chioccia': {687}
# 'giardinetto': {688, 1269}
# 'dalla': {1424, 689, 1500, 854}
# 'peppa': {689}
# 'fuoco': {692}
# 'sacro': {692}
# 'tola': {693}
# 'rasa': {693}
# 'dalie': {694}
# 'fagioli': {694, 1159}
# 'mazzucchelli': {695}
# 'sapio': {696}
# 'essenziale': {697}
# 'convito': {698, 1813}
# 'venaria': {698}
# 'pierino': {699}
# 'penati': {699}
# 'rendenèr': {700}
# 'alpine': {700}
# 'iris': {701}
# 'maurizio': {702}
# 'palta': {704}
# 'granoturco': {705}
# 'forma': {706}
# 'menzaghi': {707}
# 'pergola': {708, 1773}
# 'seta': {1499, 710}
# 'antonio': {710}
# 'guida': {710}
# 'corone': {711}
# 'ciacco': {713}
# 'daní': {714}
# 'w': {715}
# 'villadorata': {715}
# 'country': {715}
# 'farmacia': {716, 1383}
# 'ponte': {1651, 717, 1295}
# 'pietra': {717}
# 'benso': {718}
# 'fabio': {719}
# 'vale': {719}
# 'andree': {720}
# 'dell'arco': {721}
# 'bricconi': {722}
# 'carignano': {723}
# 'quintessenza': {725}
# 'già': {1724, 727}
# 'votapentole': {727}
# 'l'': {728}
# 'ciocio': {728}
# 'suvereto': {728}
# 'pineta': {1816, 729, 1719}
# 'fefa': {730}
# 'magenes': {731}
# '4': {732, 1341}
# 'cuochi': {732}
# 'luisl': {734}
# 'meucci': {735}
# 'culinaria': {736}
# 'coxinendi': {737}
# 'cantuccio': {738}
# 'shiroya': {739}
# 'miniere': {741}
# 'gustàre': {742}
# 'oltrecucina': {742}
# 'essencia': {743}
# 'wicky's': {744}
# 'innovative': {744}
# 'cuisine': {744}
# 'salinari': {745}
# 'lerchner's': {746}
# 'runggen': {746}
# 'ensama': {748}
# 'pesce': {1457, 748}
# 'capitano': {1964, 749}
# 'tipico': {749}
# 'opera02': {751}
# 'risorgimento': {753}
# 'tortuga': {754, 1709}
# 'credenziere': {755}
# 'miglio': {757}
# '210': {757}
# 'verbano': {758}
# 'giurista': {759}
# 'lattanzi': {761}
# 'luminist': {762}
# 'cafè': {762}
# 'l'agave': {763}
# 'tosca': {765}
# 'carlo': {1698, 766}
# 'camillo': {1632, 766}
# 'oltremare': {767}
# 'kisté': {768}
# 'easy': {768}
# 'buscone': {769}
# 'all'oro': {770}
# 'stilla': {771}
# 'salegrosso': {1953, 772}
# 'aleotti': {773}
# 'qafiz': {774}
# 'bros'': {1510, 775}
# 'shalai': {776}
# 'federici': {777}
# 'dina': {778}
# 'wine': {1075, 1003, 780}
# 'experiences': {780}
# 'felter': {781}
# 'baccanale': {782}
# 'fana': {783}
# 'molo': {784, 1052}
# 'ratanà': {785}
# 'alexis': {786}
# '1877': {786}
# 'frantoio': {1280, 787, 1156}
# 'principe': {805, 1678, 1810, 788, 1206}
# 'dodici': {789}
# 'fontane': {789}
# 'verso': {1056, 790}
# 'capitaneo': {790}
# 'limonaia': {791}
# 'l'angolino': {792}
# 'filippo': {792, 1620}
# 'sostansa': {793}
# 'dragone': {794}
# 'noce': {795}
# 'all'olivo': {796}
# 'gambero': {797, 1198}
# 'quadri': {798, 1527}
# 'italia': {799}
# ''petito': {800}
# 'sintesi': {801}
# 'visibilio': {802}
# 'monesi': {803}
# 'orta': {803}
# 'boccolicchio': {804}
# 'belludia': {805}
# 'cortiletto': {806}
# 'condividere': {807}
# 'manzoni': {808}
# 'emiliane': {809}
# 'moroseta': {810}
# 'butterfly': {811}
# 'asina': {812}
# 'lalchimia': {813}
# 'balin': {814}
# 'sestri': {814}
# 'levante': {814}
# 'guido': {1752, 1034, 942, 815}
# 'riva': {816, 1514}
# 'musciora': {817}
# 'gusto': {1520, 818, 1203, 1941, 1275, 1117}
# '64': {819}
# 'casina': {820}
# 'l'arcangelo': {821}
# 'sensi': {1134, 1396, 822, 831}
# 'ba': {823}
# 'testiere': {825}
# 'pennestri': {826}
# 'liberty': {828}
# 'metrò': {829}
# 'aprudia': {830}
# 'luigi': {832, 1027, 1149}
# 'lepore': {832}
# 'augurio': {833}
# 'chiesa': {834}
# 'sant'anna': {835}
# 'preséf': {837}
# 'nazionale': {1150, 838}
# 'miky': {839}
# 'babette': {840}
# 'cavour': {841, 1402}
# 'oblige': {842}
# 'favellina': {843}
# 'frangipane': {844}
# 'fiorentino': {845}
# 'fossa': {846}
# 'livello': {847}
# '1': {847}
# 'covo': {848}
# 'zest': {849}
# 'cucinaeat': {850}
# 'osaka': {851}
# 'moessmer': {852}
# 'norbert': {852}
# 'niederkofler': {852}
# 'iacobucci': {853}
# 'libera': {854}
# 'local': {855}
# 'leon': {856}
# 'laite': {857}
# 'sarri': {858}
# 'cenere': {859}
# 'museum': {859}
# 'bacucco': {860}
# 'miculan': {861}
# 'equilibrio': {862}
# 'toe': {864}
# 'drûe': {864}
# 'buca': {865, 1467, 1833}
# 'dell'arcimboldo': {866}
# 'centro': {867, 965}
# 'cardiga': {868}
# 'schironi': {868}
# 'peperosa': {869}
# 'gritta': {870}
# 'corbezzoli': {871}
# 'uovodiseppia': {872}
# 'ahimè': {873}
# 'giovanelli': {874}
# 'rueda': {875}
# 'gaucha': {875}
# 'burde': {876}
# 'doretto': {877}
# 'punta': {878}
# 'lena': {878}
# 'cipasso': {879}
# 'molteni': {880}
# 'canonica': {881}
# 'bucaccia': {882}
# 'kus': {883}
# 'forte': {884}
# '48': {884}
# 'rispoli': {885}
# 'inalto': {886}
# 'dolomites': {886}
# 'delle': {1798, 999, 1513, 1554, 887, 1243}
# 'chiavi': {1845, 887}
# 'dogma': {888}
# 'perbellini': {1152, 889, 994, 1838}
# '12': {889, 1707}
# 'apostoli': {889}
# 'felicin': {890}
# 'fiaschetteria': {891}
# 'toscano': {892}
# 'barolino': {893}
# 'cedrone': {894}
# 'pellico': {896}
# '3': {896}
# 'torchi': {897}
# 'derthona': {898}
# 'hermitage': {899}
# 'verde': {900, 1230}
# 'tri': {901}
# 'siochètt': {901}
# 'zanze': {902}
# 'xvi': {902}
# 'cocun': {903}
# 'cellar': {903}
# 'ronchi': {904}
# 'rò': {904}
# 'fagiano': {905}
# 'sushisen': {907}
# 'bel': {909}
# 'ami': {909}
# 'funghetto': {910}
# 'risacca': {911}
# 'buatta': {912}
# 'popolana': {912}
# 'scrigno': {913}
# 'mercati': {914}
# 'sgarra': {915}
# 'strecciolo': {916}
# ''l': {917}
# 'ors': {917}
# 'sustanza': {918}
# 'sichelburg': {919}
# 'platano': {920}
# 'med': {921}
# 'pomposa': {922}
# 'gras': {922}
# 'grifone': {923}
# 'sissi': {924}
# 'pista': {925}
# 'alpenrose': {926}
# 'sea': {927}
# 'front': {927}
# 'pasta': {927}
# 'madonnetta': {928}
# 'ab': {929}
# 'zio': {930}
# 'manuela': {931, 1372}
# 'donna': {932, 1068}
# 'carmela': {932}
# 'soms': {933}
# 'nero': {1434, 1043, 1844, 934}
# 'diana's': {935}
# 'remo': {936}
# 'cariolato': {936}
# 'sorriso': {939}
# 'maiella': {940}
# 'rimulas': {941}
# 'costigliole': {942}
# 'coltivare': {943}
# 'next2': {944}
# 'vele': {945}
# 'bracali': {946}
# 'namo': {948}
# 'ristobottega': {948}
# 'raieü': {950}
# 'lazaroun': {951}
# 'derby': {952}
# 'grill': {952}
# 'umberto': {953, 1910}
# 'pescheria': {954}
# 'fighine': {955}
# 'doc': {956}
# 'speranzina': {957}
# 'relais': {1426, 957}
# 'cantoni': {958}
# 'calvi': {959}
# 'tigli': {960}
# 'cedrare': {961}
# 'merlo': {962}
# 'meta': {963}
# '700': {964}
# 'laria': {966}
# 'sücar': {967}
# 'brüsc': {967}
# 'sotto': {968, 1724}
# 'l'arco': {968, 1724}
# 'filo': {969}
# 'cuccagna': {970}
# 'giro': {970}
# 'vite': {1624, 1209, 970}
# 'odino': {971}
# 'zia': {972}
# 'dimora': {973}
# 'ulmo': {973}
# 'vineyard': {974}
# 'maialetto': {976}
# 'sangiovesa': {977}
# 'cadelach': {978}
# 'format': {979}
# 'michelasso': {981}
# 'caracol': {983}
# 'nole': {984}
# 'poldo': {985}
# 'gianna': {985, 1019}
# 'segnavento': {986}
# 'apollonia': {987}
# 'madonnina': {988}
# 'azotea': {989}
# 'octavin': {990}
# 'apostelstube': {991}
# 'sole': {992}
# 'ranco': {992}
# 'madia': {993, 1682}
# '50': {995}
# 'kalò': {995}
# 'dai': {1161, 996, 1015}
# 'coghi': {996}
# 'nostrano': {997}
# 'posillipo': {998}
# 'fattoria': {1685, 999}
# 'torri': {999}
# 'elementi': {1000}
# 'europa': {1002}
# 'hebbo': {1003}
# 'deli': {1003}
# 'l'antico': {1004}
# 'dry': {1005}
# 'aged': {1005}
# 'domenico': {1589, 1006, 1943}
# 'loggia': {1007}
# 'futura': {1008, 1625}
# 'piemontese': {1009}
# 'bebop': {1010}
# 'sere': {1218, 1011}
# 'storica': {1012, 1453}
# 'trillo': {1013}
# 'bacchus': {1014}
# 'musi': {1015}
# 'bianca': {1016, 1801}
# 'mestieri': {1017}
# 'suinsom': {1018}
# 'frades': {1938, 1021}
# 'saracino': {1022}
# 'romanè': {1023}
# 'piastrino': {1025}
# 'sibilla': {1026}
# 'taglienti': {1027}
# 'dell'orco': {1028}
# 'brughiera': {1380, 1029}
# 'krone': {1030}
# 'caravella': {1031}
# '1959': {1031}
# 'cestello': {1032}
# 'firenze': {1032, 1929}
# 'l'officina': {1033}
# 'ps': {1035}
# 'glam': {1036}
# 'l'armadillo': {1037}
# 'cut': {1038}
# 'cattedrali': {1040}
# 'asti': {1040}
# 'dell'alba': {1041}
# 'tavernetta': {1042}
# 'oro': {1555, 1043}
# 'līmū': {1044}
# 'dell'orologio': {1045}
# 'lpv': {1048}
# 'ducale': {1049}
# 'lineadombra': {1050}
# 'indigeno': {1051}
# 'forme': {1054}
# 'rei': {1055}
# 'natura': {1055}
# 'michelangelo': {1055}
# 'mammoliti': {1055}
# 'ghiottone': {1056}
# 'cacciani': {1057}
# 'rosmarino': {1058}
# 'carter': {1061}
# 'oblio': {1061}
# 'borgia': {1063}
# 'grow': {1065}
# 'calandrino': {1066}
# 'spinechile': {1067}
# 'mangiare': {1068}
# 'bere': {1068}
# 'uomo': {1068}
# 'zero': {1069}
# 'primo': {1070}
# 'mamma': {1071}
# 'passion': {1072}
# 'quarantunododici': {1073}
# 'gennaro': {1074, 1885}
# 'amitrano': {1074}
# 'dine': {1075, 1420}
# 'rocca': {1077}
# 'balìce': {1078}
# 'kitchen': {1079}
# 'mildas': {1080}
# 'meletti': {1081}
# 'fiore': {1082}
# 'evo': {1083}
# 'christian': {1084}
# 'manuel': {1084}
# 'vascello': {1085}
# 'stuzzichino': {1086}
# 'café': {1088, 1531, 1655}
# 'les': {1088}
# 'paillotes': {1088}
# 'amistà': {1089}
# 'paolo': {1090, 1868, 1150}
# 'barbara': {1090}
# 'agritur': {1091}
# 'mas': {1091}
# 'cecchini': {1092}
# 'solociccia': {1092}
# 'nove': {1346, 1093}
# 'faraglioni': {1094}
# 'dolce': {1096}
# 'stil': {1096}
# 'novo': {1096, 1530}
# 'reggia': {1096}
# 'casale': {1097}
# 'ferrovia': {1097}
# 'falconiere': {1098}
# 'tenerumi': {1099}
# 'mec': {1100}
# 'mame': {1101}
# 'green': {1102}
# 'supper': {1103}
# 'toblino': {1104, 1197}
# 'vesta': {1105}
# 'lu': {1106}
# 'pisantinu': {1106}
# 'vairo': {1107}
# 'volturno': {1107}
# 'lombarda': {1108}
# 'h20': {1109}
# 'francescana': {1110}
# 'flauto': {1111}
# 'pan': {1111}
# 'perla': {1112, 1862, 1726}
# 'persef': {1113}
# 'grual': {1114}
# 'paca': {1115}
# 'ida': {1116}
# 'acanto': {1118}
# 'moka': {1119}
# 'trabe': {1120}
# 'case': {1121}
# 'saracca': {1121}
# 'agriturismo': {1736, 1122}
# 'sceppa': {1123}
# 'cesar': {1124}
# 'erbaluigia': {1125}
# 'jamantè': {1126}
# 'paradiso': {1127}
# 'marchesani': {1128}
# 'st': {1921, 1131}
# 'remy': {1131}
# 'violetta': {1132}
# 'gabbiano': {1770, 1476, 1133}
# '1983': {1936, 1133}
# 'gioele': {1135}
# 'brindo': {1136}
# 'l'insolita': {1137}
# 'soldi': {1137}
# 'salotti': {1138}
# 'lama': {1139}
# 'orto': {1140}
# 'convivio': {1141}
# 'troiani': {1141}
# 'venissa': {1142}
# 'feltrinelli': {1143}
# 'desco': {1144}
# 'bavaglino': {1145}
# 'baylon': {1146}
# 'degusteria': {1147, 1262}
# 'gigante': {1147}
# 'abba': {1148}
# 'pomata': {1149}
# 'griffa': {1150}
# 'glicine': {1151}
# 'millo': {1153}
# 'sabir': {1154}
# 'zash': {1155}
# 'saqua': {1156}
# 'nida': {1157}
# 'alpes': {1158}
# 'fuga': {1158}
# 'vescovado': {1160}
# 'mazzeri': {1161}
# 'coppola': {1162}
# 'colmetto': {1163}
# 'bur': {1164}
# 'alex': {1165}
# '20': {1518, 1166}
# 'posti': {1166, 1583}
# 'cortile': {1935, 1418, 1167}
# '1908': {1168, 1377}
# 'scaraboci': {1169}
# 'geppi': {1171}
# 'albergo': {1172}
# 'l'argine': {1173}
# 'vencò': {1173}
# 'jacopo': {1174}
# 'maeba': {1175}
# 'macello': {1176, 1652}
# 'mu': {1177}
# 'dimsum': {1177}
# 'platani': {1178}
# 'linfa': {1179}
# 'brite': {1180}
# 'larieto': {1180}
# 'branciforte': {1181}
# 'bertini': {1182}
# 'jalantuùmene': {1183}
# 'brezza': {1184}
# 'chill': {1184}
# 'anna': {1185}
# 'stuben': {1185}
# 'benedet': {1186}
# 'maragoncello': {1187}
# 'camiano': {1188}
# 'es': {1189}
# 'cantinaristorante': {1189}
# 'arva': {1190}
# 'beccaria': {1191}
# 'valle': {1192}
# 'osmosi': {1193}
# 'margherita': {1194}
# 'locale': {1195}
# 'lillotatini': {1199}
# 'piraña': {1200}
# 'atman': {1202}
# 'bàcaro': {1203}
# 'gatto': {1844, 1204, 1230}
# 'fra'': {1205}
# 'fiusch': {1205}
# 'cerami': {1206}
# 'acerorosso': {1207}
# 'd'angelo': {1208}
# 'dentella': {1211}
# 'spiriti': {1212}
# 'battipalo': {1213}
# 'autem': {1214}
# 'ceresio': {1215}
# 'suscettibile': {1216}
# 'salerno': {1216}
# 'george': {1217, 1921}
# 'aria': {1338, 1219}
# 'gerry': {1220}
# 'momento': {1221}
# '25': {1221}
# 'savi': {1222}
# 'rio': {1223}
# 'gasthofstube': {1224}
# 'stafler': {1224}
# 'barca': {1225, 1977}
# 'zanzara': {1226}
# 'sapì': {1227}
# 'massimo': {1228, 1252}
# 'camia': {1228}
# 'gorini': {1229}
# 'tiberio': {1233}
# 'chiosco': {1234}
# 'coeur': {1235}
# 'bois': {1235}
# 'cappuccini': {1236}
# 'francesco': {1236}
# 'calandre': {1237}
# 'mezzolitro': {1238}
# 'mondschein': {1239}
# 'buriani': {1240}
# '1967': {1240}
# 'afro': {1241}
# 'ora': {1242}
# 'd'aria': {1242}
# 'grazie': {1243}
# 'elisabetta': {1244}
# 'gimmi': {1245}
# 'pizzini': {1246}
# 'gnocchetto': {1247}
# 'bivio': {1248}
# 'edelweiss': {1249}
# 'canova': {1250}
# 'capestrano': {1251}
# 'gucci': {1252}
# 'bottura': {1252}
# 'assonica': {1253}
# 'kürbishof': {1254}
# 'len': {1255}
# 'opificio': {1256}
# 'crespi': {1257}
# 'panzanelle': {1259}
# 'crotto': {1261}
# 'valtellina': {1261}
# 'alighiero': {1263}
# 'truth': {1264}
# 'boccon': {1265}
# 'divino': {1265}
# 'carusu': {1266}
# 'u'': {1267}
# 'vulesce': {1267}
# 'fradis': {1268}
# 'minoris': {1268}
# 'esplanade': {1270}
# 'l'ostì': {1271}
# 'chalet': {1272, 1513}
# 'gerard': {1272}
# 'bluh': {1273}
# 'furore': {1273}
# 'xinge': {1275}
# 'moma': {1276}
# 'vert': {1277}
# 'dattilo': {1278}
# 'cavallini': {1279}
# 'sala': {1281}
# 'grappoli': {1281}
# 'refettorio': {1282}
# 'ciotola': {1283}
# 'chat': {1284}
# 'qui': {1284}
# 'rit': {1284}
# 'pesa': {1286}
# 'beccaccino': {1287}
# 'capuccina': {1288}
# 'viandante': {1290}
# 'gerani': {1291}
# 'albergaccio': {1292}
# 'castellina': {1292}
# 'sine': {1293}
# 'pinto': {1293}
# 'attilio': {1294}
# 'nerina': {1296}
# 'casamare': {1297}
# 'pompiere': {1298}
# 'veglio': {1299}
# 'terramira': {1300}
# 'naj': {1301}
# 'grandi': {1302}
# 'basilica': {1302}
# 'passo': {1303}
# 'olmo': {1304}
# 'faggio': {1305}
# 'bertaina': {1306}
# 'l'acino': {1307}
# 'clemente': {1308}
# 'magorabin': {1309}
# 'aurora': {1600, 1310}
# 'pentole': {1311}
# 'provette': {1311}
# 'dolada': {1312}
# 'galline': {1313}
# 'vitello': {1314}
# 'estro': {1315}
# 'stornello': {1318}
# 'ancòra': {1319}
# 'pupi': {1320}
# 'all'osteria': {1321}
# 'voltalacarta': {1322}
# 'dante': {1323}
# 'l'aia': {1325}
# 'cappellani': {1325}
# 'marin': {1326}
# 'sereno': {1328}
# 'nicolo': {1329}
# 'piazzetta': {1769, 1330}
# 'cattedrale': {1330}
# 'olio': {1331}
# 'rada': {1332}
# 'untitled': {1333}
# 'piano': {1334}
# 'nascostoposto': {1335}
# 'pignano': {1336}
# 'angelo': {1337}
# 'sabatelli': {1337}
# 'almatò': {1339}
# 'ciance': {1341}
# 'achilli': {1342}
# 'parlamento': {1342}
# 'l'erba': {1343}
# 'baia': {1344}
# 'silenzio': {1344}
# 'scodelle': {1346}
# 'dopolavoro': {1348}
# 'tantris': {1349}
# 'grenier': {1350}
# 'primula': {1351}
# 'capinera': {1352}
# 'feria': {1354}
# 'razzo': {1356}
# 'duanima': {1357}
# 'pasina': {1358}
# 'l'asinello': {1359}
# 'mood': {1360}
# 'raia': {1361}
# 'carla': {1362}
# 'meltemi': {1363}
# 'indiniò': {1364}
# 'profumi': {1365}
# 'cous': {1365}
# 'rear': {1366}
# 'inkiostro': {1367}
# 'enoclub': {1368}
# 'filip': {1370}
# 'tancredi': {1371}
# 'cantina': {1490, 1372}
# 'abbruzzino': {1373, 1422}
# 'oltre': {1373, 1455}
# 'evan's': {1374}
# 'ginevra': {1375}
# 'makorè': {1376}
# 'conte': {1378}
# 'matto': {1378}
# 'fracia': {1379}
# 'fiorfiore': {1381}
# 'terrae': {1382}
# 'sani': {1383}
# 'banchieri': {1384}
# 'balzi': {1385}
# 'rossi': {1385}
# 'gibas': {1386}
# 'annetta': {1387}
# 'scopiccio': {1388}
# 'controcorrente': {1745, 1389}
# 'amanõ': {1391}
# 'l'ostreria': {1392}
# 'fratelli': {1392, 1721}
# 'pavesi': {1392}
# 'acciuga': {1393}
# 'camini': {1394}
# 'politano': {1397}
# 'mesadoria': {1398}
# 'campamac': {1399}
# 'luciano': {1400, 1654, 1638}
# 'ostaria': {1401, 1658}
# 'tyrol': {1401}
# 'mecca': {1402}
# 'grinzane': {1402}
# 'volta': {1403}
# 'fuenti': {1403}
# 'blasio': {1403}
# 'delfino': {1404}
# 'estrò': {1405}
# 'mater1apr1ma': {1406}
# 'viaggio': {1407}
# 'claudio': {1723, 1407}
# 'melis': {1407}
# 'impronte': {1408}
# 'vespri': {1409}
# 'coquus': {1410}
# 'veritas': {1411}
# 'tiglio': {1412}
# 'quartopiano': {1413}
# 'nilo': {1414}
# 'langosteria': {1855, 1415}
# 'paraggi': {1415}
# 'meraviglioso': {1417}
# 'moderna': {1417}
# 'arabo': {1418}
# 'kelina': {1420}
# 'scannabue': {1421}
# 'leggenda': {1423}
# 'frati': {1423}
# 'alda': {1424}
# 'chandelle': {1425}
# 'lucenti': {1427}
# 'nonno': {1428}
# '13': {1683, 1428}
# 'nicolin': {1429}
# 'savô': {1430}
# 'tartufo': {1432}
# 'exé': {1433}
# 'corsaro': {1434}
# 'cravero': {1435}
# 'imàgo': {1437}
# 'quel': {1438}
# 'fantastico': {1438}
# 'giovedì': {1438}
# 'serendepico': {1439}
# 'hazama': {1440}
# 'sui': {1441}
# 'generis': {1441}
# 'done': {1442}
# 'impronta': {1489, 1443, 1871}
# 'scalco': {1444}
# 'grasso': {1444}
# 'umami': {1445}
# 'cucine': {1662, 1447}
# 'nervi': {1447}
# 'botero': {1448}
# 'omakase': {1449}
# 'opera': {1450}
# 'baliaggio': {1451}
# 'anto': {1452}
# 'robi': {1452}
# 'baracca': {1453}
# 'kucina': {1454}
# 'sanbrite': {1456}
# 'crocifisso': {1458}
# 'rampina': {1459}
# 'mercanti': {1460}
# 'pinchiorri': {1462}
# 'àbitat': {1463}
# 'andreina': {1464}
# 'feudo': {1465}
# 'sant'antonio': {1467}
# 'miranda': {1469}
# 'adelaide': {1470}
# '30': {1476, 1573, 1471}
# 'ciro': {1471}
# 'cascella': {1471}
# 'kaiserkron': {1472}
# 'rapisarda': {1473}
# 'mima': {1475}
# 'credenza': {1477}
# 'specus': {1478}
# 'visione': {1479}
# 'living': {1479}
# 'felix': {1480}
# 'basso': {1480, 1485}
# 'home': {1480}
# 'apollonio': {1481}
# 'horto': {1482}
# 'tano': {1486}
# 'passami': {1486}
# 'l'olio': {1486}
# 'marinaio': {1487}
# 'sottomarino': {1488}
# 'd'acqua': {1489}
# 'frosch': {1491}
# 'miseria': {1492}
# 'nobiltà': {1492}
# 'malenco': {1493}
# 'caruso': {1494}
# 'cavalluccio': {1495}
# 'grottino': {1496}
# '1126': {1497}
# 'palomba': {1498}
# 'sushi': {1499}
# 'gioconda': {1609, 1500}
# 'l'ottava': {1501}
# 'nota': {1501}
# 'boivin': {1503}
# 'petrucci': {1505, 1965}
# 'cracco': {1536, 1506, 1531}
# 'portofino': {1506}
# 'trentino': {1507}
# 'maltagliati': {1508}
# 'concezione': {1509}
# 'cantinone': {1511}
# 'sport': {1511}
# 'hotel': {1511}
# 'alpina': {1890, 1511}
# 'koinè': {1512}
# 'anita': {1513}
# 'prà': {1513}
# 'nasse': {1513}
# 'winckels': {1515}
# 'mammaròssa': {1517}
# 'rucola': {1518}
# 'mocellin': {1519}
# 'padovanino': {1519}
# 'doppio': {1520}
# 'marechiaro': {1521}
# 'tufo': {1522}
# 'allegro': {1522}
# 'narciso': {1523}
# 'fontanina': {1524}
# 'marcelin': {1525}
# '219': {1526}
# 'angiòmacelleria': {1528}
# 'bolle': {1529}
# 'aubergine': {1532}
# 'bislakko': {1533}
# 'votavota': {1534}
# 'pagnanelli': {1535}
# 'galleria': {1536}
# 'arca': {1538}
# 'burattini': {1539}
# 'l'argaj': {1540}
# 'salamensa': {1541}
# 'ronchettino': {1542}
# 'dongiò': {1543}
# 'l'acchiatura': {1545}
# 'kleine': {1546}
# 'flamme': {1546}
# '85': {1547}
# 'pilone': {1548}
# 'metodo': {1549}
# 'palais': {1550}
# 'royal': {1550}
# 'vie': {1551}
# 'villoresi': {1552}
# 'bacilieri': {1553}
# 'esperidi': {1554}
# 'brinca': {1556}
# 'fermata': {1557}
# 'favri': {1558}
# 'piacentino': {1559}
# 'silene': {1560}
# 'piano35': {1561}
# 'blum': {1562}
# 'tamo': {1563}
# 'lanterne': {1565}
# 'motelombroso': {1566}
# 'upepidde': {1567}
# 'volt': {1568}
# 'danielcanzian': {1569}
# 'galli': {1570}
# 'maurì': {1571}
# 'burjè': {1572}
# '1968': {1572, 1943}
# 'pajara': {1574}
# 'toscana': {1575}
# 'forno': {1575}
# 'henri': {1576}
# 'pignata': {1577}
# 'arborina': {1578}
# 'abraxas': {1579}
# 'signore': {1580}
# 'te': {1580}
# 'ne': {1580}
# 'ringrazi': {1580}
# 'mirko's': {1581}
# 'onda': {1582}
# '28': {1583}
# 'retroscena': {1584}
# 'nni': {1586}
# 'lausta': {1586}
# 'secondo': {1587}
# 'ruris': {1588}
# 'baggio': {1590}
# 'giulio': {1601, 1594}
# 'spuntino': {1595}
# 'ruota': {1596}
# 'rezzano': {1597}
# 'vissani': {1598}
# 'personale': {1599}
# 'terrinoni': {1601}
# 'joca': {1602}
# 'rifugio': {1604, 1663}
# 'col': {1604}
# 'alt': {1604}
# 'procaccini': {1605}
# 'lapprodo': {1606}
# 'angeli': {1639, 1607}
# 'guallina': {1608}
# 'pietramare': {1610}
# 'natural': {1610}
# 'pallavicina': {1611}
# 'scatto': {1612}
# 'castagni': {1613}
# 'gassenwirt': {1614}
# 'franciacorta': {1615}
# 'pascucci': {1616}
# 'porticciolo': {1616}
# 'rigoletto': {1617}
# 'narcisi': {1618}
# 'l'a': {1619}
# 'l'accademia': {1619}
# 'serpillo': {1621}
# 'otto': {1623}
# 'geleng': {1623}
# 'dim': {1628}
# 'sum': {1628}
# 'l'arcade': {1629}
# 'musciara': {1630}
# 'leone': {1631}
# 'monzù': {1633}
# 'lioni': {1635}
# 'ferrata': {1636}
# 'mirasole': {1637}
# 'foce': {1640}
# 'dall'antonia': {1641}
# 'fiamma': {1643}
# 'cremisi': {1643}
# 'giovanni': {1644}
# 'coldana': {1645}
# 'fugascina': {1646}
# 'mirto': {1647}
# 'acquolina': {1649}
# 'vitique': {1650}
# 'maxi': {1653}
# 'severino': {1654}
# 'quinson': {1655}
# 'saffron': {1656}
# 'cerreta': {1657}
# 'pignatelli': {1658}
# 'dell'accademia': {1659}
# 'regallo': {1661}
# 'abocar': {1662}
# 'fuciade': {1663}
# 'a'': {1792, 1665}
# 'paranza': {1665}
# 'giulia': {1666}
# 'terrazzo': {1666}
# 'petes': {1667}
# 'accursio': {1668}
# 'sot'ajarchi': {1669}
# 'dulchemente': {1670}
# 'ego': {1671}
# 'john': {1672}
# 'restaurantcasamadre': {1672}
# 'mingone': {1673}
# 'nelli': {1674}
# 'ortica': {1675}
# 'collina': {1676}
# 'mos': {1677}
# 'pirata': {1678}
# 'palazzon': {1679}
# 'ilario': {1680}
# 'vinciguerra': {1680}
# 'buco': {1681}
# 'comuni': {1683}
# 'deste': {1684}
# 'grottaione': {1685}
# 'vero': {1686}
# 'venetian': {1686}
# 'roots': {1686}
# 'ciambella': {1687}
# 'costantino': {1688}
# 'estia': {1689}
# 'losanna': {1690}
# 'papaveri': {1691}
# 'papere': {1691}
# 'scuderie': {1692}
# 'sabaude': {1692}
# 'alajmo': {1693}
# 'cortina': {1693}
# 'hanswirt': {1694}
# 'incàlmo': {1695}
# 'minimi': {1696}
# 'bul': {1697}
# 'magno': {1698}
# 'vedel': {1700}
# 'dolomieu': {1701}
# 'gong': {1703}
# 'lamberti': {1704}
# 'gina': {1705}
# 'fiorile': {1706}
# 'giardini': {1708}
# 'rodo': {1708}
# 'l'ancora': {1709}
# 'lautier': {1710}
# 'altran': {1712}
# 'hidalgo': {1713}
# 'foresteria': {1714}
# 'melograno': {1715}
# 'parizzi': {1716}
# 'elephant': {1717}
# 'capriolino': {1718}
# 'regio': {1720}
# 'bruzzone': {1721}
# 'lio': {1722}
# 'pellegrini': {1722}
# 'nobuya': {1725}
# 'salotto': {1727}
# 'botte': {1728}
# 'strattoria': {1730}
# 'countryside': {1732}
# 'ricanatti': {1734}
# 'canelli': {1735}
# 'crippa': {1735}
# 'ferdy': {1736}
# 'marsupino': {1737}
# '1901': {1737}
# 'lalibera': {1738}
# 'leonefelice': {1739}
# 'vista': {1739}
# 'contatto': {1740}
# 'ling's': {1741}
# 'ravioleria': {1741}
# 'migrante': {1741}
# 'l'imbuto': {1742}
# 'canapone': {1743}
# 'fantinilake': {1744}
# 'time': {1744}
# 'zappatori': {1746}
# 'angiolina': {1748}
# 'fiori': {1749}
# 'camelì': {1750}
# 'kaiseki': {1751}
# 'armando': {1753}
# 'pantheon': {1753}
# 'cimino': {1754}
# '1895': {1754}
# 'fenicottero': {1755}
# 'durnwald': {1757}
# 'pascalucci': {1758}
# 'burba': {1759}
# 'saletta': {1760}
# 'peca': {1761}
# 'old': {1762}
# 'friend': {1762}
# 'portico': {1763}
# '26': {1764, 1780}
# 'bandiera': {1765}
# 'mogano': {1766}
# 'rambaldi': {1767}
# 'paeto': {1768}
# 'milù': {1769}
# 'allombra': {1770}
# 'pode': {1771}
# 'n'uovo': {1772}
# 'meridiana': {1774}
# 'barone': {1775}
# 'fogher': {1776}
# 'fagiolino': {1777}
# 'lupaia': {1778}
# 'campiello': {1779}
# 'l'atelier': {1780}
# 'pescarinosapori': {1781}
# 'sera': {1782}
# 'morer': {1784}
# 'tirabusciò': {1785}
# 'carpaccio': {1786}
# 'focarile': {1787}
# 'vignola': {1788}
# 'gigi': {1789}
# 'venise': {1790}
# 'giocondo': {1791}
# 'cuncuma': {1792}
# 'nido': {1793}
# 'picchio': {1793}
# 'armaniristorante': {1794}
# 'poli': {1795}
# 'stazione': {1795}
# 'miil': {1796}
# 'bellavista': {1797}
# 'refezione': {1800}
# 'baccofurore': {1803}
# 'parolina': {1804}
# 'serendib': {1805}
# 'grantosco': {1806}
# 'monte': {1807}
# 'vallagarina': {1808}
# 'magazzino': {1809}
# '52': {1809}
# 'filippino': {1811}
# 'michelaccio': {1812}
# 'curina': {1813}
# 'felice': {1814}
# 'casu': {1817}
# 'ristorantino': {1818}
# 'dino': {1818}
# 'tivoli': {1819}
# 'lanzagallo': {1820}
# 'gologone': {1821}
# 'nin': {1822}
# 'sant'uffizio': {1823}
# 'piè': {1824}
# 'tofana': {1824}
# 'pinocchio': {1825}
# 'campi': {1826}
# 'marcello': {1826}
# 'tonno': {1827}
# 'corsa': {1827}
# 'cippi': {1828, 1901}
# '1976': {1828}
# 'campanara': {1829}
# 'castagneto': {1831}
# 'nuova': {1832}
# 'terre': {1834}
# 'alte': {1834}
# 'antinè': {1835}
# 'perso': {1836}
# 'becco': {1837}
# 'civetta': {1837}
# 'beati': {1838}
# 'belle': {1839}
# 'parti': {1839}
# 'anticofurlo': {1840}
# 'bruxaboschi': {1842}
# 'menegaldo': {1843}
# 'artifex': {1846}
# 'stüa': {1847}
# 'michil': {1847}
# 'alpenroyal': {1848}
# 'fè': {1850}
# 'attico': {1851}
# 'saporium': {1929, 1852}
# 'amerigo': {1853}
# 'marotta': {1854}
# 'tasso': {1856}
# 'spurcacciuna': {1857}
# 'gardenia': {1858}
# 'rune': {1861}
# 'buoi': {1863}
# 'ciabot': {1864}
# 'svevia': {1866}
# 'emozioni': {1867}
# 'teverini': {1868}
# 'perrotta': {1869}
# 'josef': {1872}
# 'mondo': {1873}
# 'nives': {1874}
# 'banchi': {1875}
# 'péniche': {1876}
# 'primero': {1877}
# 'spoon': {1878}
# 'didù': {1879}
# 'caldora': {1880}
# 'cumpari': {1881}
# 'turiddu': {1881}
# 'lux': {1882}
# 'lucis': {1882}
# 'zàghara': {1883}
# 'panevin': {1884}
# 'miramonti': {1886}
# 'l'altro': {1886}
# 'pozzo': {1887}
# 'capitan': {1889}
# 'cittadella': {1889}
# '177': {1891}
# 'toledo': {1891}
# 'wistèria': {1892}
# 'ladinia': {1893}
# 'saturnino': {1894}
# 'bersagliere': {1895}
# '20tre': {1896}
# 'cocchi': {1897}
# 'casamatta': {1898}
# 'gimmy's': {1899}
# 'arnolfo': {1902}
# 'tubladel': {1903}
# 'penacio': {1905}
# 'lumira': {1906}
# 'mia': {1907}
# 'indaco': {1908}
# 'all'enoteca': {1909}
# 'soprattutto': {1912}
# 'cosmo': {1913}
# 'pimpinella': {1914}
# 'elena': {1915}
# 'arbustico': {1916}
# 'bino': {1918}
# 'portolano': {1919}
# 'carracci': {1920}
# 'heinz': {1921}
# 'beck': {1921}
# 'cappello': {1922}
# 'vitantonio': {1924}
# 'lombardo': {1924}
# 'ingalera': {1926}
# 'l'orciaia': {1927}
# 'trequarti': {1928}
# 'bentōteca': {1930}
# 'bikini': {1931}
# 'saraceno': {1933}
# 'olivi': {1934}
# 'gainn': {1937}
# 'latini': {1939}
# 'cjasal': {1940}
# 'sarti': {1941}
# 'mandra': {1942}
# 'cacciatore': {1944}
# 'subida': {1944}
# 'impero': {1945}
# 'cantinella': {1946}
# 'corniola': {1947}
# 'cardinale': {1948}
# 'virginia': {1949}
# 'casin': {1950}
# 'gamba': {1950}
# 'serrae': {1951}
# 'fiesole': {1951}
# 'laurin': {1952}
# 'panna': {1954}
# 'ménage': {1955}
# 'ciaspole': {1956}
# 'pietracupa': {1957}
# 'arianna': {1958}
# 'riso': {1959}
# 'amaro': {1959}
# 'coria': {1960}
# 'murruai': {1961}
# 'feva': {1962}
# 'oste': {1963}
# 'finsterwirt': {1963}
# 'braunwirt': {1966}
# 'prima': {1967}
# 'torrente': {1968}
# 'essentia': {1969}
# 'ritrovo': {1970}
# 'winter': {1971}
# 'florence': {1971}
# 'voce': {1972}
# 'sanlorenzo': {1973}
# 'viva': {1974}
# 'l'uva': {1975}
# 'malto': {1975}
# 'tanzer': {1976}
# 'serafino': {1978}
# 'roscioli': {1979}
# 'zamboni': {1980}
# 'faletta': {1981}
# '1881': {1981}

# %% [markdown]
# The following cell implements the **advanced search**:
#
# - **`search_inverted_indices`**:
#   - Searches indexed fields for terms provided by the user.
#   - Calculates a score for each result based on term matches.
#
# - **`advanced_search_with_filters`**:
#   - Applies the same cleaning process to both user input and indexed fields.
#   - Filters raw results using additional criteria: **price range**, **accepted credit cards**, and **offered services**.
#   - Sorts and returns the most relevant results.

# %%
# Function to search within indexed fields and calculate scores
def search_inverted_indices(query, indices):
    results = defaultdict(int) 

    for field, terms in query.items():
        if field not in indices:
            continue
        for term in terms.split(): 
            if term in indices[field]:
                for idx in indices[field][term]:
                    results[idx] += 1 
    
    return results

def advanced_search_with_filters(user_input, indices, df, top_n=10):
    price_order = {
        '€': 1,
        '€€': 2,
        '€€€': 3,
        '€€€€': 4
    }

    # Apply the same cleaning process used for specific fields in the dataset to the user input as well.
    query = {
        'restaurantName_clean': clean_text_with_stopwords(user_input['restaurantName']),
        'city_clean': clean_text_with_stopwords(user_input['city']),
        'cuisineType_clean': clean_text_with_stopwords(user_input['cuisineType'])
    }

    raw_results = search_inverted_indices(query, indices)

    # Filter the results based on additional criteria such as price, region, accepted credit cards, and offered services.
    filtered_results = []
    for idx, score in raw_results.items():
        row = df.loc[idx]

        # Price filter
        if not (price_order[row['priceRange']] >= price_order[user_input['priceRange'][0]] and
                price_order[row['priceRange']] <= price_order[user_input['priceRange'][1]]):
            continue

        # Cards Filter
        if not all(card in row['creditCards_clean'] for card in user_input['creditCards']):
            continue

        # Services Filter
        if not all(facility in row['facilitiesServices_clean'] for facility in user_input['facilities']):
            continue

        filtered_results.append((idx, score))

    sorted_results = sorted(filtered_results, key=lambda x: x[1], reverse=True)
    top_results = df.loc[[r[0] for r in sorted_results[:top_n]]]

    return top_results[['restaurantName', 'address', 'cuisineType', 'priceRange', 'website']]

# %%
# UI
ui = UserInputInterface()
ui.display()
# Out:
# Tab(children=(VBox(children=(Text(value='', description='Restaurant:', placeholder='Name of restaurant'), Text…
# Button(description='Start Search', style=ButtonStyle())
# Output()

# %%
#Result
user_input = ui.get_values()
print(user_input)
indices = {
    'restaurantName_clean': restaurant_name_index,
    'city_clean': city_index,
    'cuisineType_clean': cuisine_type_index
}
results = advanced_search_with_filters(user_input, indices, df)
display(results)
# Out:
# {'restaurantName': '', 'city': 'Rome', 'cuisineType': '', 'priceRange': ('€€€€', '€€€€'), 'regions': [], 'creditCards': [], 'facilities': ['Terrace']}
#                    restaurantName                    address  \
# 770                       All'Oro  via Giuseppe Pisanelli 25
# 54                      Mirabelle   via di Porta Pinciana 14
# 1601      Per Me Giulio Terrinoni      vicolo del Malpasso 9
# 708                    La Pergola            via Cadlolo 101
# 610                     Orma Roma         via Boncompagni 31
# 1382                 Mater Terrae               largo Febo 2
# 624   Il Ristorante - Niko Romito          via di Ripetta 73
# 506                         Aroma           via Labicana 125
#
#                               cuisineType priceRange  \
# 770        Creative, Italian Contemporary       €€€€
# 54                   Italian Contemporary       €€€€
# 1601                    Italian, Creative       €€€€
# 708   Mediterranean Cuisine, Contemporary       €€€€
# 610       Italian Contemporary, Colombian       €€€€
# 1382             Vegetarian, Contemporary       €€€€
# 624                  Italian Contemporary       €€€€
# 506                        Modern Cuisine       €€€€
#
#                                                 website
# 770                    https://www.ristorantealloro.it/
# 54                             https://www.mirabelle.it
# 1601                     https://www.giulioterrinoni.it
# 708         https://romecavalieri.com/it/la-pergola-it/
# 610                              http://www.ormaroma.it
# 1382                   https://www.biohotelraphael.com/
# 624   https://www.bulgarihotels.com/it_IT/rome/dinin...
# 506               https://www.manfredihotels.com/aroma/
